# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Геннадий, привет!👋</b>
#
# Меня зовут Алексей Гриб, и я буду ревьюером твоего проекта.
#
# Сразу хочу предложить в дальнейшем общаться на "ты" - надеюсь, так будет комфортнее:) Но если это неудобно, обязательно дай знать, и мы придумаем что-нибудь ещё!
#
# Цель ревью - не искать ошибки в твоём проекте, а помочь тебе сделать твою работу ещё лучше, устранив недочёты и приблизив её к реальным задачам специалиста по работе с данными. Поэтому не расстраивайся, если что-то не получилось с первого раза - это нормально, и это поможет тебе вырасти!
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> похвала, рекомендации «со звёздочкой», полезные лайфхаки, которые сделают и без того красивое решение ещё более элегантным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> некритичные ошибки или развивающие рекомендации на будущее.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# критичные ошибки, которые обязательно нужно исправить.
# </div>
#
#
# Пожалуйста, не удаляй мои комментарии, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Ты также можешь задавать свои вопросы, реагировать на мои комментарии, делать пометки и пояснения - полная творческая свобода! Но маленькая просьба - пускай они будут отличаться от моих комментариев, это поможет избежать путаницы в нашем общении:)
# Например, вот так:
#
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *твой текст*
# </div>
#
# Давай посмотрим на твой проект!

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Комментарий ревьюера </b>
#
# Геннадий, я вижу, исполнение твоего кода начинается в ячейке с номером, который отличается от единицы (см.скрин ниже). Перед отправкой проекта (особенно в случае работы локально или в другом окружении) стоит проверять работоспособность кода __на платформе__ — это можно сделать, нажав на панели Jupiter Hub ``Kernel`` и ``Restart & Run All`` (см скриншот ниже).
#
# ![](https://i.postimg.cc/yd19rYf6/Screenshot-428.png)
#
# Важно также убедиться, что все ячейки проекта исполнились - можно просто пролистать работу до конца и убедиться, что последняя ячейка исполнена. Такая проверка поможет тебе убедиться, что твоё решение будет должным образом воспроизведено во время ревью или во время передачи его заказчику - это очень важный этап, пренебрегать которым не стоит:)
#
# На втором сборном проекте проверка воспроизводимости решения - одно из ключевых условий для начала работы над ним, поэтому перед отправкой работы на следующую итерацию ревью убедись в её работоспособности на платформе по инструкции выше.

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202025-03-27%20%D0%B2%2016.58.27.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202025-03-27%20%D0%B2%2016.58.27.png)

# %% [markdown]
# **Описание проекта**
#
# Компания «Работа с заботой» предоставила данные с характеристиками сотрудников компании. Среди них — уровень удовлетворённости сотрудника работой в компании. Эту информацию получили из форм обратной связи: сотрудники заполняют тест-опросник, и по его результатам рассчитывается доля их удовлетворённости от 0 до 1, где 0 — совершенно неудовлетворён, 1 — полностью удовлетворён.
#
# Первая задача — построить модель, которая сможет предсказать уровень удовлетворённости сотрудника на основе данных заказчика.
# Удовлетворённость работой напрямую влияет на отток сотрудников. А предсказание оттока — одна из важнейших задач HR-аналитиков. Внезапные увольнения несут в себе риски для компании, особенно если уходит важный сотрудник.
#
# Вторая задача — построить модель, которая сможет на основе данных заказчика предсказать то, что сотрудник уволится из компании.
#
# Заказчик предоставил данные с признаками:
#
# •	id — уникальный идентификатор сотрудника;
#
# •	dept — отдел, в котором работает сотрудник;
#
# •	level — уровень занимаемой должности;
#
# •	workload — уровень загруженности сотрудника;
#
# •	employment_years — длительность работы в компании (в годах);
#
# •	last_year_promo — показывает, было ли повышение за последний год;
#
# •	last_year_violations — показывает, нарушал ли сотрудник трудовой договор за последний год;
#
# •	supervisor_evaluation — оценка качества работы сотрудника, которую дал руководитель;
#
# •	salary — ежемесячная зарплата сотрудника;
#
# •	job_satisfaction_rate — уровень удовлетворённости сотрудника работой в компании, целевой признак.
#
# **План исследования**
#
# Задача 1.
#
# Шаг 1. Загрузка файлов с данными: тренировочная выборка, входные признаки тестовой выборки, целевой признак тестовой выборки.
#
# Шаг 2. Предобработка данных.
#
# Шаг 3. Исследовательский анализ данных
#
# Шаг 4. Подготовка данных в пайплайне, с учетом особенностей признаков и моделей и использованием двух кодировщиков.
#
# Шаг 5. Обучение двух моделей. Одна линейная модель, вторая — дерево решений. Подбор гиперпараметров. Выбор лучшей модели на основе метрики SMAPE.
#
# Шаг 6. Оформление выводов.
#
# Задача 2.
#
# Шаг 1. Загрузка файлов с данными: тренировочная выборка, входные признаки тестовой выборки, целевой признак тестовой выборки.
#
# Шаг 2. Предобработка данных в пайплайне.
#
# Шаг 3. Исследовательский анализ данных. Составление портрета «уволившегося сотрудника». Прверка утверждения, что уровень удовлетворённости сотрудника работой в компании влияет на увольнение.
#
# Шаг 4. Добавление нового входного признака job_satisfaction_rate, предсказанного лучшей моделью в первой задаче.
#
# Шаг 5. Подготовка данных в пайплайне, с учетом особенности признаков и моделей и использованием двух кодировщиков.
#
# Шаг 6. Обучение трех моделей с подбором гиперпараметров. Проверка качества лучшей модели метрикой ROC-AUC. Критерий: ROC-AUC≥0.91 на тестовой выборке.
#
# Шаг 7. Выводы о том, какая модель справилась лучше и почему.
#
# Общий вывод по проекту.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Хорошее вступление!
#
# В нём есть всё, что необходимо, чтобы понять суть проекта с первых строк отчёта!

# %%
# !pip install -U scikit-learn -q
# !pip install phik -q

# %%
# импорт необходимых библиотек
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import phik

# импорт функций, классов и модулей
from phik.report import plot_correlation_matrix
from phik import report
from phik import significance_matrix
from sklearn.linear_model import LinearRegression
from sklearn.dummy import DummyRegressor
from sklearn.dummy import DummyClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler, MinMaxScaler, RobustScaler, PolynomialFeatures
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.datasets import make_classification
from sklearn import svm
from sklearn import model_selection, metrics
from sklearn.metrics import make_scorer, roc_auc_score
from sklearn.ensemble import RandomForestClassifier
from scipy.stats import ttest_ind, mannwhitneyu, shapiro, levene

# %%
# Глобальные параметры
RANDOM_STATE = 42
#TEST_SIZE = 0.25

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Библиотеки импортировали - отлично!

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
# Ты импортируешь библиотеки и модули, которые не используешь в проекте - так делать не стоит, так как ты забиваешь окружение лишними  инструментами.
#
# В блоке импорта стоит оставить только то, что реально используется в проекте.
#
# Переменная `TEST_SIZE` не используется в проекте - не стоит её создавать.

# %% [markdown]
# ## Задача 1

# %% [markdown]
# ### Загрузка данных

# %%
# Чтение CSV-файла и сохранение в DataFrame с названием 'train_job_satisfaction_rate'
#train_job_satisfaction_rate = pd.read_csv('/datasets/train_job_satisfaction_rate.csv')

# Вывод информации о DataFrame
#print(train_job_satisfaction_rate.info())

# Отображение первых пяти строк DataFrame
#train_job_satisfaction_rate.head()

# %%
# Чтение CSV-файла и сохранение в DataFrame с названием 'train_job_satisfaction_rate'
# Указываем пути к файлам
pth1 = '/datasets/train_job_satisfaction_rate.csv' # Серверный путь
pth2 = './datasets/train_job_satisfaction_rate.csv'  # Локальный относительный путь

# Проверяем существование файла по первому пути
if os.path.exists(pth1):
    train_job_satisfaction_rate = pd.read_csv(pth1)
# Если файл по первому пути не найден, проверяем второй путь
elif os.path.exists(pth2):
    train_job_satisfaction_rate = pd.read_csv(pth2)
else:
    print('Файл не найден по указанным путям.')

# Вывод информации о DataFrame
print(train_job_satisfaction_rate.info())

# Отображение первых пяти строк DataFrame
print(train_job_satisfaction_rate.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     4000 non-null   int64
#  1   dept                   3994 non-null   object
#  2   level                  3996 non-null   object
#  3   workload               4000 non-null   object
#  4   employment_years       4000 non-null   int64
#  5   last_year_promo        4000 non-null   object
#  6   last_year_violations   4000 non-null   object
#  7   supervisor_evaluation  4000 non-null   int64
#  8   salary                 4000 non-null   int64
#  9   job_satisfaction_rate  4000 non-null   float64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 312.6+ KB
# None
#        id        dept   level workload  employment_years last_year_promo  \
# 0  155278       sales  junior   medium                 2              no
# ...

# %%
# Чтение CSV-файла и сохранение в DataFrame с названием 'test_features'
#test_features = pd.read_csv('/datasets/test_features.csv')

# Вывод информации о DataFrame
#print(test_features.info())

# Отображение первых пяти строк DataFrame
#test_features.head()

# %%
# Чтение CSV-файла и сохранение в DataFrame с названием 'test_features'
# Указываем пути к файлам
pth1 = '/datasets/test_features.csv' # Серверный путь
pth2 = './datasets/test_features.csv'  # Локальный относительный путь

# Проверяем существование файла по первому пути
if os.path.exists(pth1):
    test_features = pd.read_csv(pth1)
# Если файл по первому пути не найден, проверяем второй путь
elif os.path.exists(pth2):
    test_features = pd.read_csv(pth2)
else:
    print('Файл не найден по указанным путям.')

# Вывод информации о DataFrame
print(test_features.info())

# Отображение первых пяти строк DataFrame
print(test_features.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   dept                   1998 non-null   object
#  2   level                  1999 non-null   object
#  3   workload               2000 non-null   object
#  4   employment_years       2000 non-null   int64
#  5   last_year_promo        2000 non-null   object
#  6   last_year_violations   2000 non-null   object
#  7   supervisor_evaluation  2000 non-null   int64
#  8   salary                 2000 non-null   int64
# dtypes: int64(4), object(5)
# memory usage: 140.8+ KB
# None
#        id       dept   level workload  employment_years last_year_promo  \
# 0  485046  marketing  junior   medium                 2              no
# 1  686555         hr  junior   medium                 1              no
# ...

# %%
# Чтение CSV-файла и сохранение в DataFrame с названием 'test_target_job_satisfaction_rate'
#test_target_job_satisfaction_rate = pd.read_csv('/datasets/test_target_job_satisfaction_rate.csv')

# Вывод информации о DataFrame
#print(test_target_job_satisfaction_rate.info())

# Отображение первых пяти строк DataFrame
#test_target_job_satisfaction_rate.head()

# %%
# Чтение CSV-файла и сохранение в DataFrame с названием 'test_target_job_satisfaction_rate'
# Указываем пути к файлам
pth1 = '/datasets/test_target_job_satisfaction_rate.csv' # Серверный путь
pth2 = './datasets/test_target_job_satisfaction_rate.csv'  # Локальный относительный путь

# Проверяем существование файла по первому пути
if os.path.exists(pth1):
    test_target_job_satisfaction_rate = pd.read_csv(pth1)
# Если файл по первому пути не найден, проверяем второй путь
elif os.path.exists(pth2):
    test_target_job_satisfaction_rate = pd.read_csv(pth2)
else:
    print('Файл не найден по указанным путям.')

# Вывод информации о DataFrame
print(test_target_job_satisfaction_rate.info())

# Отображение первых пяти строк DataFrame
print(test_target_job_satisfaction_rate.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   job_satisfaction_rate  2000 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 31.4 KB
# None
#        id  job_satisfaction_rate
# 0  130604                   0.74
# 1  825977                   0.75
# 2  418490                   0.60
# 3  555320                   0.72
# 4  826430                   0.08

# %% [markdown]
# <div class='alert alert-info'><b>
#
# Комментарий студента:</b>
#
# Датасеты в хорошем состоянии, но требуют минимальной очистки (проверка пропусков). Данные имеют соотвествующий тип и готовы для анализа, визуализации и построения моделей предсказания удовлетворенности сотрудников.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>
#
# Данные загрузили.
#
# При считывании данных из файла здорово перестраховывать себя от ошибок, связанных, например, с неверным указанием пути к файлу. А иногда бывает, что работаешь с файлом локально, выгружаешь его на сервер, ожидая, что он будет принимать данные, которые лежат на том же сервере, а код падает с ошибкой, потому что путь к файлу не поменялся с локального на серверный.
#
# Для этого, например, можно использовать конструкцию `try-except`: сначала пробуешь локальный путь, при возникновении ошибки используется серверный путь (подробнее можешь почитать тут: https://pythonworld.ru/tipy-dannyx-v-python/isklyucheniya-v-python-konstrukciya-try-except-dlya-obrabotki-isklyuchenij.html).
#
# Но еще лучше использовать библиотеку `os` - её использование позволит тебе проверять существование указанных директорий (что может быть актуально при одновременной работа на локальном и сетевом окружении) и загружать данные из существующей директории, избегая ошибок. Как пример:
#
#     import os
#
#     pth1 = '/folder_1/data.csv'
#     pth2 = '/folder_2/data.csv'
#
#     if os.path.exists(pth1):
#         query_1 = pd.read_csv(pth1)
#     elif os.path.exists(pth2):
#         query_1 = pd.read_csv(pth2)
#     else:
#         print('Something is wrong')
#
# Ещё на этапе считывания данных можно спарсить дату: за это действие отвечает параметр `parse_dates` метода `read_csv()`, в него нужно передать список с названием полей-дат, и в большинстве случаев дата будет корректно преобразована в нужный формат сразу:)
# Также на этапе считывания данных можно задать индекс-столбец - за это действие отвечает параметр `index_col`.

# %% [markdown]
# ### Предобработка данных

# %%
# Проверка наличия и подсчет дубликатов строк по столбцу 'id' датафрейма 'train_job_satisfaction_rate'
duplicate_count = train_job_satisfaction_rate['id'].duplicated().sum()
print(f"Количество дубликатов: {duplicate_count}")
# Out:
# Количество дубликатов: 0

# %%
# Исключаем из проверки уникальных значений первую колонку 'id'
columns_to_check = train_job_satisfaction_rate.columns[1:]

# Вывод уникальных значений в колонках датафрейма
for col in columns_to_check:
    print(f"{col}: {train_job_satisfaction_rate[col].unique()}")
# Out:
# dept: ['sales' 'hr' 'technology' 'purchasing' 'marketing' nan]
# level: ['junior' 'middle' 'sinior' nan]
# workload: ['medium' 'high' 'low']
# employment_years: [ 2  1  4  7  9  6  3 10  8  5]
# last_year_promo: ['no' 'yes']
# last_year_violations: ['no' 'yes']
# supervisor_evaluation: [1 5 2 3 4]
# salary: [24000 38400 12000 18000 22800 30000 56400 52800 13200 54000 19200 40800
#  34800 27600 26400 33600 50400 15600 14400 25200 72000 31200 32400 48000
#  43200 46800 58800 84000 44400 39600 37200 21600 28800 62400 60000 42000
#  49200 55200 57600 68400 45600 51600 64800 80400 20400 61200 76800 69600
#  16800 36000 63600 81600 66000 74400 67200 70800 73200 75600 79200 94800
#  78000 88800 92400 85200 91200 98400 96000 97200]
# job_satisfaction_rate: [0.58 0.76 0.11 0.37 0.2  0.78 0.56 0.44 0.14 0.47 0.74 0.42 0.32 0.57
#  0.16 0.69 0.33 0.64 0.39 0.8  0.79 0.17 0.65 0.18 0.19 0.49 0.63 0.22
#  0.23 0.5  0.35 0.3  0.77 0.88 0.59 0.21 0.36 0.85 0.7  0.48 0.6  0.1
# ...

# %%
# Проверка наличия и подсчет дубликатов строк по столбцу 'id' датафрейма 'test_features'
duplicate_count = test_features['id'].duplicated().sum()
print(f"Количество дубликатов: {duplicate_count}")
# Out:
# Количество дубликатов: 0

# %%
# Исключаем из проверки уникальных значений первую колонку 'id'
columns_to_check = test_features.columns[1:]

# Вывод уникальных значений в колонках датафрейма
for col in columns_to_check:
    print(f"{col}: {test_features[col].unique()}")
# Out:
# dept: ['marketing' 'hr' 'sales' 'purchasing' 'technology' nan ' ']
# level: ['junior' 'middle' 'sinior' nan]
# workload: ['medium' 'low' 'high' ' ']
# employment_years: [ 2  1  5  6  3  9  7  4  8 10]
# last_year_promo: ['no' 'yes']
# last_year_violations: ['no' 'yes']
# supervisor_evaluation: [5 4 3 1 2]
# salary: [28800 30000 19200 40800 42000 26400 49200 62400 14400 36000 33600 44400
#  27600 12000 64800 20400 34800 15600 18000 50400 31200 51600 16800 43200
#  52800 32400 37200 58800 24000 21600 48000 45600 25200 63600 61200 56400
#  38400 46800 55200 13200 39600 54000 57600 68400 22800 72000 81600 60000
#  66000 67200 70800 76800 79200 69600 94800 82800 80400 87600 86400 96000
#  78000 75600 73200 84000 88800 92400]

# %% [markdown]
# <div class='alert alert-info'><b>
#
# Комментарий студента:</b>
#
# Необходимо заменить в таблице пробелы ' ' пустым значениям NaN.
#
# </div>

# %%
# Замена пробелов в столбцах 'dept' и 'workload' на NaN (пропущенные значения), чтобы корректнее обрабатывать данные
test_features['dept'] = test_features['dept'].replace(' ', np.nan)
test_features['workload'] = test_features['workload'].replace(' ', np.nan)

# Вывод уникальных значений в колонках датафрейма
for col in columns_to_check:
    print(f"{col}: {test_features[col].unique()}")
# Out:
# dept: ['marketing' 'hr' 'sales' 'purchasing' 'technology' nan]
# level: ['junior' 'middle' 'sinior' nan]
# workload: ['medium' 'low' 'high' nan]
# employment_years: [ 2  1  5  6  3  9  7  4  8 10]
# last_year_promo: ['no' 'yes']
# last_year_violations: ['no' 'yes']
# supervisor_evaluation: [5 4 3 1 2]
# salary: [28800 30000 19200 40800 42000 26400 49200 62400 14400 36000 33600 44400
#  27600 12000 64800 20400 34800 15600 18000 50400 31200 51600 16800 43200
#  52800 32400 37200 58800 24000 21600 48000 45600 25200 63600 61200 56400
#  38400 46800 55200 13200 39600 54000 57600 68400 22800 72000 81600 60000
#  66000 67200 70800 76800 79200 69600 94800 82800 80400 87600 86400 96000
#  78000 75600 73200 84000 88800 92400]

# %%
# Проверка наличия и подсчет дубликатов строк по столбцу 'id' датафрейма 'test_target_job_satisfaction_rate'
duplicate_count = test_target_job_satisfaction_rate['id'].duplicated().sum()
print(f"Количество дубликатов: {duplicate_count}")
# Out:
# Количество дубликатов: 0

# %%
# Исключаем из проверки уникальных значений первую колонку 'id'
columns_to_check = test_target_job_satisfaction_rate.columns[1:]

# Вывод уникальных значений в колонках датафрейма
for col in columns_to_check:
    print(f"{col}: {test_target_job_satisfaction_rate[col].unique()}")
# Out:
# job_satisfaction_rate: [0.74 0.75 0.6  0.72 0.08 0.76 0.64 0.38 0.14 0.59 0.91 0.78 0.7  0.79
#  0.34 0.81 0.23 0.4  0.58 0.77 0.68 0.24 0.42 0.69 0.47 0.35 0.71 0.83
#  0.61 0.65 0.37 0.45 0.63 0.82 0.16 0.89 0.28 0.32 0.88 0.36 0.33 0.31
#  0.27 0.73 0.53 0.26 0.57 0.2  1.   0.56 0.67 0.19 0.52 0.43 0.12 0.11
#  0.21 0.13 0.49 0.22 0.86 0.46 0.41 0.48 0.29 0.87 0.66 0.8  0.55 0.5
#  0.51 0.62 0.85 0.84 0.15 0.39 0.25 0.9  0.07 0.1  0.92 0.3  0.44 0.18
#  0.93 0.54 0.96 0.09 0.99 0.17 0.95 0.06 0.94 0.03 0.98 0.97 0.04 0.05]

# %% [markdown]
# <div class='alert alert-info'><b>
#
# Комментарий студента:</b>
#
# В столбцах dept (отдел) и workload (уровень загруженности) пробелы были заменены на NaN, что корректно обозначает пропущенные данные. Это важно для последующего анализа, позволяет избежать ошибок при статистических расчетах, упрощает фильтрацию и очистку данных.
#
# Ошибка в написании уровня должности ('sinior' вместо 'senior') во всех датасетах на дальнейший анализ не повлияет, поэтому название оставим прежним.
#
# В столбце id датафреймов test_target_job_satisfaction_rate, test_features и test_target_job_satisfaction_rate дубликаты отсутствуют. Это означает, что каждая запись уникальна. А данные готовы для объединения с другими таблицами по ключу id.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>
#
# Аномалия обработана корректно. В целом она могла бы быть обработана и в `Pipeline`, при настройке энкодеров на обработку новых значений признаков, которые не были на момент обучения энкодера. Также для её обработки можно было бы создать отдельный `SimpleImputer`.

# %% [markdown]
# ### Исследовательский анализ данных

# %%
# Словарь для отображения названий колонок
column_names = {
    'dept': 'Отдел',
    'level': 'Уровень должности',
    'workload': 'Уровень загруженности',
    'last_year_promo': 'Повышение за последний год',
    'last_year_violations':'Нарушения за последний год',
    'employment_years': 'Длительность работы',
    'supervisor_evaluation': 'Оценка работы сотрудника',
    'salary': 'Зарплата сотрудника',
    'job_satisfaction_rate': 'Удовлетворенность сотрудника',
    'quit': 'Увольнение сотрудника'
}

# %%
'''
# Создание списка количественных столбцов датасета train_job_satisfaction_rate
num_col = ['employment_years', 
           'supervisor_evaluation', 
           'salary', 
           'job_satisfaction_rate']

# Функция построение распределений количественных признаков датасета
def plot_columns_hist_box(df, columns):
    for column in columns:
        if column in df.columns:
            plt.figure(figsize=(12, 5))
            
            # Гистограмма
            plt.subplot(1, 2, 1)
            plt.xlabel('Значения')
            plt.ylabel('Частота')
            plt.title(f'Гистограмма {column_names.get(column, column)}')
            sns.histplot(df[column], color=(0.3, 0.7, 1))
            
            # Боксплот
            plt.subplot(1, 2, 2)
            plt.xlabel('Значения')
            plt.title(f'Боксплот {column_names.get(column, column)}')
            sns.boxplot(x=df[column], color=(0.7, 0.3, 1))
            
            plt.tight_layout()
            plt.show()
        else:
            print(f"Столбец '{column}' не найден в датафрейме.")

# Ппостроение распределений количественных признаков датасета train_job_satisfaction_rate
plot_columns_hist_box(train_job_satisfaction_rate, num_col)
'''
# Out:
# '\n# Создание списка количественных столбцов датасета train_job_satisfaction_rate\nnum_col = [\'employment_years\', \n           \'supervisor_evaluation\', \n           \'salary\', \n           \'job_satisfaction_rate\']\n\n# Функция построение распределений количественных признаков датасета\ndef plot_columns_hist_box(df, columns):\n    for column in columns:\n        if column in df.columns:\n            plt.figure(figsize=(12, 5))\n            \n            # Гистограмма\n            plt.subplot(1, 2, 1)\n            plt.xlabel(\'Значения\')\n            plt.ylabel(\'Частота\')\n            plt.title(f\'Гистограмма {column_names.get(column, column)}\')\n            sns.histplot(df[column], color=(0.3, 0.7, 1))\n            \n            # Боксплот\n            plt.subplot(1, 2, 2)\n            plt.xlabel(\'Значения\')\n            plt.title(f\'Боксплот {column_names.get(column, column)}\')\n            sns.boxplot(x=df[column], color=(0.7, 0.3, 1))\n            \n            plt.ti
# ...

# %%
# Разделение признаков на количественные и дискретные
continuous_columns = ['salary', 'job_satisfaction_rate']
discrete_columns = ['employment_years', 'supervisor_evaluation']

# Функция для построения графиков для количественных признаков
def plot_continuous_features(df, columns):
    for column in columns:
        if column in df.columns:
            plt.figure(figsize=(12, 5))
            
            # Гистограмма
            plt.subplot(1, 2, 1)
            plt.xlabel('Значения')
            plt.ylabel('Частота')
            plt.title(f'Гистограмма {column_names.get(column, column)}')
            sns.histplot(df[column], color=(0.3, 0.7, 1), kde=True)
            
            # Боксплот
            plt.subplot(1, 2, 2)
            plt.xlabel('Значения')
            plt.title(f'Боксплот {column_names.get(column, column)}')
            sns.boxplot(x=df[column], color=(0.7, 0.3, 1))
            
            plt.tight_layout()
            plt.show()
        else:
            print(f"Столбец '{column}' не найден в датафрейме.")

# Функция для построения графиков для дискретных признаков
def plot_discrete_features(df, columns):
    for column in columns:
        if column in df.columns:
            plt.figure(figsize=(8, 5))
            plt.title(f'Распределение {column_names.get(column, column)}')
            sns.countplot(x=df[column], palette='Blues')
            plt.xlabel('Значения')
            plt.ylabel('Частота')
            plt.xticks(rotation=45)
            plt.tight_layout()
            plt.show()
        else:
            print(f"Столбец '{column}' не найден в датафрейме.")

# Построение графиков для количественных признаков
plot_continuous_features(train_job_satisfaction_rate, continuous_columns)

# Построение графиков для дискретных признаков
plot_discrete_features(train_job_satisfaction_rate, discrete_columns)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> `employment_years` и `supervisor_evaluation` - дискретные признаки, для их анализа нужнен тип графиков, который на каждое уникальные значение признака строит свою корзину. Например, можно использовать `sns.countplot`.
#
# Для этих признаков также не нужно строить ящики с усами, так как признак имеет, скорее, распределение категориального признака, пусть и представленного уже в численном виде.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
'''
# Создание списка количественных столбцов датасета test_features
num_col_1 = ['employment_years', 
           'supervisor_evaluation', 
           'salary']

# Построение распределений количественных признаков датасета test_features
plot_columns_hist_box(test_features, num_col_1)
'''
# Out:
# "\n# Создание списка количественных столбцов датасета test_features\nnum_col_1 = ['employment_years', \n           'supervisor_evaluation', \n           'salary']\n\n# Построение распределений количественных признаков датасета test_features\nplot_columns_hist_box(test_features, num_col_1)\n"

# %%
# Разделение признаков на количественные и дискретные
continuous_columns = ['salary']
discrete_columns = ['employment_years', 'supervisor_evaluation']

# Построение графиков для количественных признаков
plot_continuous_features(test_features, continuous_columns)

# Построение графиков для дискретных признаков
plot_discrete_features(test_features, discrete_columns)

# %%
# Построение распределений количественных признаков датасета test_target_job_satisfaction_rate
#plot_columns_hist_box(test_target_job_satisfaction_rate, ['job_satisfaction_rate'])

# %%
# Построение распределений количественных признаков датасета test_target_job_satisfaction_rate
plot_continuous_features(test_target_job_satisfaction_rate, ['job_satisfaction_rate'])

# %% [markdown]
# <div class='alert alert-info'><b>
#
# Комментарий студента:</b>
#
# Аномальных выбросов значений нет. Данные распределены нормально, со смещением влево по признакам "Длительность работы" и "Зарплата".
#
# </div>

# %%
# функция для построения круговых диаграмм
def create_pie_chart(df, column):
    
    # Подсчет количества уникальных значений в столбце
    counts = df[column].value_counts()

    # Создание круговой диаграммы
    fig, ax = plt.subplots(figsize=(5, 6))
    wedges, texts, autotexts = ax.pie(counts, labels=counts.index, autopct='%1.1f%%',
                                      startangle=90, counterclock=False,
                                      wedgeprops={'linewidth': 1, 'edgecolor': 'white'})

    # Настройка внешнего вида подписей
    for text in texts:
        text.set_fontsize(14)

    # Настройка процента в центре сектора
    for autotext in autotexts:
        autotext.set_color('white')
        autotext.set_fontweight('bold')
        autotext.set_fontsize(16)

    # Заголовок графика
    ax.set_title(f"Круговая диаграмма для '{column_names.get(column, column)}'", fontsize=18)

    # Показываем график
    plt.show()

# Создание списка категориальных столбцов датасета train_job_satisfaction_rate
col_col = ['dept', 'level',
           'workload', 'last_year_promo',
           'last_year_violations']

# Построение круговых диаграм категориальных признаков датасета train_job_satisfaction_rate
for col in col_col:
    create_pie_chart(train_job_satisfaction_rate, col)

# %%
# Создание списка категориальных столбцов датасета test_features
col_col_1 = ['dept', 'level',
           'workload', 'last_year_promo',
           'last_year_violations']


# Построение круговых диаграм категориальных признаков датасета test_features
for col in col_col_1:
    create_pie_chart(test_features, col)

# %%
'''
# Вычисляем корреляционную матрицу phik датасета train_job_satisfaction_rate
phik_corr_matrix = train_job_satisfaction_rate.phik_matrix()

# Преобразование индекса и столбцов корреляционной матрицы
phik_corr_matrix = phik_corr_matrix.reindex(columns=[c for c in phik_corr_matrix.columns if c != 'id'],
                                            index=[i for i in phik_corr_matrix.index if i != 'id'])

# Применение словаря для отображения названий колонок
phik_corr_matrix = phik_corr_matrix.rename(index=column_names, columns=column_names)

# Визуализация корреляционной матрицы
plt.figure(figsize=(15, 10))
sns.heatmap(phik_corr_matrix, annot=True, cmap='coolwarm', vmin=0, vmax=1)
plt.title('Корреляционная матрица (phi_K)')
plt.show()
'''
# Out:
# "\n# Вычисляем корреляционную матрицу phik датасета train_job_satisfaction_rate\nphik_corr_matrix = train_job_satisfaction_rate.phik_matrix()\n\n# Преобразование индекса и столбцов корреляционной матрицы\nphik_corr_matrix = phik_corr_matrix.reindex(columns=[c for c in phik_corr_matrix.columns if c != 'id'],\n                                            index=[i for i in phik_corr_matrix.index if i != 'id'])\n\n# Применение словаря для отображения названий колонок\nphik_corr_matrix = phik_corr_matrix.rename(index=column_names, columns=column_names)\n\n# Визуализация корреляционной матрицы\nplt.figure(figsize=(15, 10))\nsns.heatmap(phik_corr_matrix, annot=True, cmap='coolwarm', vmin=0, vmax=1)\nplt.title('Корреляционная матрица (phi_K)')\nplt.show()\n"

# %%
# Список непрерывных признаков
interval_cols = ['salary', 'job_satisfaction_rate']

# Вычисляем корреляционную матрицу phik с явным указанием непрерывных признаков
phik_corr_matrix = train_job_satisfaction_rate.phik_matrix(interval_cols=interval_cols)

# Преобразование индекса и столбцов корреляционной матрицы
phik_corr_matrix = phik_corr_matrix.reindex(columns=[c for c in phik_corr_matrix.columns if c != 'id'],
                                            index=[i for i in phik_corr_matrix.index if i != 'id'])

# Применение словаря для отображения названий колонок
phik_corr_matrix = phik_corr_matrix.rename(index=column_names, columns=column_names)

# Визуализация корреляционной матрицы
plt.figure(figsize=(15, 10))
sns.heatmap(phik_corr_matrix, annot=True, cmap='coolwarm', vmin=0, vmax=1)
plt.title('Корреляционная матрица (phi_K)')
plt.show()
# Out:
# /opt/conda/lib/python3.9/site-packages/phik/data_quality.py:59: UserWarning: The number of unique values of variable id is large: 4000. Are you sure this is not an interval variable? Analysis for pairs of variables including id can be slow.
#   warnings.warn(

# %%
# Список непрерывных признаков
interval_cols = ['salary']

# Вычисляем корреляционную матрицу phik с явным указанием непрерывных признаков
phik_corr_matrix = test_features.phik_matrix(interval_cols=interval_cols)

# Преобразование индекса и столбцов корреляционной матрицы
phik_corr_matrix = phik_corr_matrix.reindex(columns=[c for c in phik_corr_matrix.columns if c != 'id'],
                                            index=[i for i in phik_corr_matrix.index if i != 'id'])

# Применение словаря для отображения названий колонок
phik_corr_matrix = phik_corr_matrix.rename(index=column_names, columns=column_names)

# Визуализация корреляционной матрицы
plt.figure(figsize=(15, 10))
sns.heatmap(phik_corr_matrix, annot=True, cmap='coolwarm', vmin=0, vmax=1)
plt.title('Корреляционная матрица (phi_K)')
plt.show()
plt.show()
# Out:
# /opt/conda/lib/python3.9/site-packages/phik/data_quality.py:59: UserWarning: The number of unique values of variable id is large: 2000. Are you sure this is not an interval variable? Analysis for pairs of variables including id can be slow.
#   warnings.warn(

# %% [markdown]
# <div class='alert alert-info'><b>
#
# Комментарий студента:</b>
#
# Наибольшее влияние на зарплату оказывают уровень должности и загруженность. Удовлетворенность сотрудника сильнее зависит от оценки его работы и отсутствия нарушений, а не от зарплаты или загруженности. Отдел, где работает человек, почти не играет роли в этих показателях. Мультиколлинеарность признаков не наблюдается.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Есть анализ корреляции - молодец, что используешь `phik` для анализа и нелинейных зависимостей.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# При использовании `phik` крайне важно настроить параметр `interval_cols`, передав ему список с названиями непрерывных признаков: если этого не сделать, библиотека своими силами будет пытаться разнести признаки по типам, и она часто делает в этом ошибки - от этого в свою очередь мы получаем некорректную оценку корреляций, так как от типа признака зависит метод оценки корреляции.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено. Однако обрати внимание, что `id` лучше исключать до применения `.phik_matrix()`, чтобы он не попадал в расчёт.

# %% [markdown]
# ### Подготовка данных в пайплайне, с учетом особенностей признаков и моделей и использованием двух кодировщиков

# %%
'''
# Объединение тестовых данных
target_features = test_target_job_satisfaction_rate.merge(test_features, on='id', how='left')

# Подготовка тренировочных данных
train_p = train_job_satisfaction_rate.drop(['id'], axis=1)
train_p.drop_duplicates(inplace=True)'''
# Out:
# "\n# Объединение тестовых данных\ntarget_features = test_target_job_satisfaction_rate.merge(test_features, on='id', how='left')\n\n# Подготовка тренировочных данных\ntrain_p = train_job_satisfaction_rate.drop(['id'], axis=1)\ntrain_p.drop_duplicates(inplace=True)"

# %%
# Объединение тестовых данных
target_features = test_target_job_satisfaction_rate.merge(test_features, on='id', how='left')

# Подготовка тренировочных данных
train_p = train_job_satisfaction_rate.drop(['id'], axis=1)

# Проверка наличия дубликатов
if train_p.duplicated().any():
    print(f"Найдено {train_p.duplicated().sum()} дубликатов.")
    # Удаление дубликатов
    train_p.drop_duplicates(inplace=True)
    print("Дубликаты успешно удалены.")
else:
    print("Дубликаты отсутствуют.")
# Out:
# Найдено 245 дубликатов.
# Дубликаты успешно удалены.

# %%
if target_features.duplicated().any():
    print(f"Найдено {target_features.duplicated().sum()} дубликатов в объединенных тестовых данных.")
    target_features.drop_duplicates(inplace=True)
else:
    print("Дубликаты в объединенных тестовых данных отсутствуют.")
# Out:
# Дубликаты в объединенных тестовых данных отсутствуют.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Молодец, что проверяешь дубликаты после удаления `id` и обрабатываешь только `train`.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Перед удалением дубликатов полезно проверять их наличие, чтобы было понимание, актуальна ли проблема.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
X_train = train_p.drop('job_satisfaction_rate', axis=1)
y_train = train_p['job_satisfaction_rate'] 
X_test = target_features.drop(['job_satisfaction_rate','id'], axis=1)
y_test = target_features['job_satisfaction_rate'] 

# Определение признаков
ohe_columns = ['dept', 'last_year_promo', 'last_year_violations']  # Для OneHotEncoder
ord_columns = ['level', 'workload']  # Для OrdinalEncoder
num_columns = ['employment_years', 'supervisor_evaluation', 'salary']  # Числовые признаки

# Пайплайн для категориальных признаков (OneHotEncoder)
ohe_pipe = Pipeline([
    ('imputer_ohe', SimpleImputer(strategy='most_frequent')),  # Обработка пропусков
    ('ohe', OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False))  # OneHotEncoding
])

# Пайплайн для порядковых признаков (OrdinalEncoder)
ord_pipe = Pipeline([
    ('imputer_before_ord', SimpleImputer(strategy='most_frequent')),  # Обработка пропусков
    ('ord', OrdinalEncoder(
        categories=[['junior', 'middle', 'senior'], ['low', 'medium', 'high']],
        handle_unknown='use_encoded_value', unknown_value=np.nan
    )),
    ('imputer_after_ord', SimpleImputer(strategy='most_frequent'))  # Обработка пропусков после кодирования
])

# Пайплайн для числовых признаков (StandardScaler)
data_preprocessor = ColumnTransformer([
    ('ohe', ohe_pipe, ohe_columns),
    ('ord', ord_pipe, ord_columns),
    ('num', StandardScaler(), num_columns)  # Масштабирование числовых признаков
], remainder='passthrough')

# Финальный пайплайн с моделью
pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', LinearRegression())  # Начальная модель
])

# %% [markdown]
# ### Обучение двух моделей (линейная и дерево решений) с подбором гиперпараметров. Выбор лучшей модели на основе метрики SMAPE.

# %%
# Параметры для GridSearchCV
param_grid = [
    {
        'models': [LinearRegression()],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  # Разные методы масштабирования
    },
    {
        'models': [DecisionTreeRegressor(random_state=RANDOM_STATE)],
        'models__max_depth': range(2, 20),  # Диапазон глубины дерева
        'models__max_features': range(2, 20),  # Количество признаков для разбиения
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  # Разные методы масштабирования
    }
]

# Определение метрики SMAPE
def smape(y_true, y_pred):
    return 100 / len(y_true) * np.sum(2 * np.abs(y_pred - y_true) / (np.abs(y_true) + np.abs(y_pred)))

smape_scorer = make_scorer(score_func=smape, greater_is_better=False)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Есть функция для оценки `sMAPE`, а также пользовательский скорринг для кросс-валидации - супер!
# </div>

# %%
# Поиск лучших гиперпараметров с помощью GridSearchCV
grid_search = GridSearchCV(
    pipe_final,
    param_grid,
    n_jobs=-1,
    cv=5,
    scoring=smape_scorer
)
grid_search.fit(X_train, y_train)

# Лучшая модель
best_model = grid_search.best_estimator_

# Вывод результатов
print(f'Лучшая модель: {type(best_model.named_steps["models"]).__name__}')
print('Лучшие параметры:', grid_search.best_params_)
print(f'Метрика SMAPE лучшей модели по кросс-валидации на обучающих данных: {round(grid_search.best_score_ * (-1), 4)}')
# Out:
# Лучшая модель: DecisionTreeRegressor
# Лучшие параметры: {'models': DecisionTreeRegressor(random_state=42), 'models__max_depth': 12, 'models__max_features': 8, 'preprocessor__num': MinMaxScaler()}
# Метрика SMAPE лучшей модели по кросс-валидации на обучающих данных: 15.8598

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Найдена лучшая модель.

# %%
# Оценка модели на тестовых данных
test_smape = smape(y_test, best_model.predict(X_test))
print(f'Метрика SMAPE лучшей модели на тестовой выборке: {round(test_smape, 4)}')
# Out:
# Метрика SMAPE лучшей модели на тестовой выборке: 14.2126

# %%
# Создание и обучение DummyRegressor
dummy_model = DummyRegressor(strategy='mean')  # Предсказываем среднее значение
dummy_model.fit(X_train, y_train)

# Оценка DummyRegressor на тестовых данных
dummy_smape = smape(y_test, dummy_model.predict(X_test))
print(f'Метрика SMAPE для DummyRegressor на тестовой выборке: {round(dummy_smape, 4)}')

# Сравнение с лучшей моделью
if test_smape < dummy_smape:
    print("Лучшая модель превосходит DummyRegressor.")
else:
    print("Лучшая модель не превосходит DummyRegressor.")
# Out:
# Метрика SMAPE для DummyRegressor на тестовой выборке: 38.2623
# Лучшая модель превосходит DummyRegressor.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Лучшую модель оценили на `test` - отличный результат!

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
# Очень важно также проверить лучшую модель на адекватность, сравнив качество её предсказаний с качеством модели, которая предсказывала бы константу - вдруг окажется, что не было бы большого смысла заниматься созданием новых признаков, тюнингом и кросс-валидацией моделей, если можно было бы просто предсказывать среднее значение тренировочной выборки?
#
# В качестве константной модели можно использовать `DummyRegressor` (https://scikit-learn.org/stable/modules/generated/sklearn.dummy.DummyRegressor.html) -  эта модель как раз создана для генерирования константных предсказаний.
#
# Важно, чтобы результат тестирования нашей модели на тествой выборке был лучше, чем результат константной модели - в противном случае наша модель является бесполезной, так как все наши усилия над проектом не принесли результата, а можель, просто предсказывющая среднее на `train`, делает нашу работу лучше.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# <div class='alert alert-info'><b>
#
# Комментарий студента:</b>
#
# Найдена лучшая модель: DecisionTreeRegressor с параметрами {'models': DecisionTreeRegressor(random_state=42), 'models__max_depth': 12, 'models__max_features': 8, 'preprocessor__num': MinMaxScaler()}
#
# Метрика SMAPE лучшей модели на обучающих данных - 15.8598; на тестовой выборке - 14.2126, что соответствует условию задачи (SMAPE <= 15.0).
#
# </div>

# %% [markdown]
# ### Оформление выводов.

# %% [markdown]
# **Общий вывод по задаче 1:**
#
# Выполнена задача поиска лучшей модели для прогнозирования уровня удовлетворённости работой (`job_satisfaction_rate`). Для оценки качества моделей использовалась метрика SMAPE, которая измеряет процентное отклонение предсказаний от истинных значений.
#
# Тестовые данные были объединены с целевой переменной через `merge` по столбцу `id`, чтобы гарантировать соответствие признаков и целевых значений. Из тренировочных данных удалены дублирующиеся строки с помощью метода `drop_duplicates`. Данные разделены на тренировочные (`X_train`, `y_train`) и тестовые (`X_test`, `y_test`), исключая идентификаторы (`id`).
#
# Для обработки пропусков категориальных признаков использован `SimpleImputer` со стратегией `most_frequent`, для числовых применён `SimpleImputer` с `mean`.
#
# Категориальные признаки `dept`, `last_year_promo`, `last_year_violations` закодированы с помощью `OneHotEncoder`. А признаки `level` и `workload` - с помощью `OrdinalEncoder`.
#
# Количественные ловые признаки (`employment_years`, `supervisor_evaluation`, `salary`) масштабированы с использованием `StandardScaler`.
#
# Для подбора модели и гиперпараметров использован пайплайн для автоматизации предобработки данных и обучения. Для поиска лучших гиперпараметров применён метод `GridSearchCV` с кросс-валидацией (5 фолдов) и метрикой SMAPE.
#
# Рассмотрены две модели:
#
# 1. Линейная регрессия (`LinearRegression`).
#
# 2. Дерево решений (`DecisionTreeRegressor`) с различными значениями глубины (`max_depth`), количества признаков для разбиения (`max_features`) и методами масштабирования (`StandardScaler`, `MinMaxScaler`, `'passthrough'`).
#
# По результатам поиска лучшая модель — это **Дерево решений** с параметрами:
#
# - Глубина: 12.
#
# - Количество признаков для разбиения: 8.
#
# - Масштабирование числовых признаков: MinMaxScaler.
#
# - Метрика SMAPE на обучающих данных: 15.8598.
#
# - SMAPE на тестовой выборке: 14.2126.
#
# Метрики на тренировочной и тестовой выборках близки, что указывает на хорошую обобщающую способность модели.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Молодец, что не забываешь про промежуточные выводы.

# %% [markdown]
# ## Задача 2

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Для этой задачи аналогичны все замечания из предыдущей в части аналогичных активностей.
#
# Ниже будут отмечены только новые замечания.

# %% [markdown]
# ### Загрузка данных.

# %%
'''
# Чтение CSV-файла и сохранение в DataFrame с названием 'train_quit'
train_quit = pd.read_csv('/datasets/train_quit.csv')

# Вывод информации о DataFrame
print(train_quit.info())

# Отображение первых пяти строк DataFrame
train_quit.head()
'''
# Out:
# "\n# Чтение CSV-файла и сохранение в DataFrame с названием 'train_quit'\ntrain_quit = pd.read_csv('/datasets/train_quit.csv')\n\n# Вывод информации о DataFrame\nprint(train_quit.info())\n\n# Отображение первых пяти строк DataFrame\ntrain_quit.head()\n"

# %%
# Чтение CSV-файла и сохранение в DataFrame с названием 'train_quit'
# Указываем пути к файлам
pth1 = '/datasets/train_quit.csv' # Серверный путь
pth2 = './datasets/train_quit.csv'  # Локальный относительный путь

# Проверяем существование файла по первому пути
if os.path.exists(pth1):
    train_quit = pd.read_csv(pth1)
# Если файл по первому пути не найден, проверяем второй путь
elif os.path.exists(pth2):
    train_quit = pd.read_csv(pth2)
else:
    print('Файл не найден по указанным путям.')

# Вывод информации о DataFrame
print(train_quit.info())

# Отображение первых пяти строк DataFrame
print(train_quit.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     4000 non-null   int64
#  1   dept                   4000 non-null   object
#  2   level                  4000 non-null   object
#  3   workload               4000 non-null   object
#  4   employment_years       4000 non-null   int64
#  5   last_year_promo        4000 non-null   object
#  6   last_year_violations   4000 non-null   object
#  7   supervisor_evaluation  4000 non-null   int64
#  8   salary                 4000 non-null   int64
#  9   quit                   4000 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 312.6+ KB
# None
#        id        dept   level workload  employment_years last_year_promo  \
# 0  723290       sales  middle     high                 2              no
# ...

# %%
'''
# Чтение CSV-файла и сохранение в DataFrame с названием 'test_features'
test_features_2 = pd.read_csv('/datasets/test_features.csv')

# Вывод информации о DataFrame
print(test_features_2.info())

# Отображение первых пяти строк DataFrame
test_features_2.head()
'''
# Out:
# "\n# Чтение CSV-файла и сохранение в DataFrame с названием 'test_features'\ntest_features_2 = pd.read_csv('/datasets/test_features.csv')\n\n# Вывод информации о DataFrame\nprint(test_features_2.info())\n\n# Отображение первых пяти строк DataFrame\ntest_features_2.head()\n"

# %%
# Чтение CSV-файла и сохранение в DataFrame с названием 'test_features_2'
# Указываем пути к файлам
pth1 = '/datasets/test_features.csv' # Серверный путь
pth2 = './datasets/test_features.csv'  # Локальный относительный путь

# Проверяем существование файла по первому пути
if os.path.exists(pth1):
    test_features_2 = pd.read_csv(pth1)
# Если файл по первому пути не найден, проверяем второй путь
elif os.path.exists(pth2):
    test_features_2 = pd.read_csv(pth2)
else:
    print('Файл не найден по указанным путям.')

# Вывод информации о DataFrame
print(test_features_2.info())

# Отображение первых пяти строк DataFrame
print(test_features_2.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   dept                   1998 non-null   object
#  2   level                  1999 non-null   object
#  3   workload               2000 non-null   object
#  4   employment_years       2000 non-null   int64
#  5   last_year_promo        2000 non-null   object
#  6   last_year_violations   2000 non-null   object
#  7   supervisor_evaluation  2000 non-null   int64
#  8   salary                 2000 non-null   int64
# dtypes: int64(4), object(5)
# memory usage: 140.8+ KB
# None
#        id       dept   level workload  employment_years last_year_promo  \
# 0  485046  marketing  junior   medium                 2              no
# 1  686555         hr  junior   medium                 1              no
# ...

# %%
'''
# Чтение CSV-файла и сохранение в DataFrame с названием 'test_target_quit'
test_target_quit = pd.read_csv('/datasets/test_target_quit.csv')

# Вывод информации о DataFrame
print(test_target_quit.info())

# Отображение первых пяти строк DataFrame
test_target_quit.head()
'''
# Out:
# "\n# Чтение CSV-файла и сохранение в DataFrame с названием 'test_target_quit'\ntest_target_quit = pd.read_csv('/datasets/test_target_quit.csv')\n\n# Вывод информации о DataFrame\nprint(test_target_quit.info())\n\n# Отображение первых пяти строк DataFrame\ntest_target_quit.head()\n"

# %%
# Чтение CSV-файла и сохранение в DataFrame с названием 'test_target_quit'
# Указываем пути к файлам
pth1 = '/datasets/test_target_quit.csv' # Серверный путь
pth2 = './datasets/test_target_quit.csv'  # Локальный относительный путь

# Проверяем существование файла по первому пути
if os.path.exists(pth1):
    test_target_quit = pd.read_csv(pth1)
# Если файл по первому пути не найден, проверяем второй путь
elif os.path.exists(pth2):
    test_target_quit = pd.read_csv(pth2)
else:
    print('Файл не найден по указанным путям.')

# Вывод информации о DataFrame
print(test_target_quit.info())

# Отображение первых пяти строк DataFrame
print(test_target_quit.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2000 non-null   int64
#  1   quit    2000 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 31.4+ KB
# None
#        id quit
# 0  999029  yes
# 1  372846   no
# 2  726767   no
# 3  490105   no
# 4  416898  yes

# %% [markdown]
# <div class='alert alert-info'><b>
#
# Комментарий студента:</b>
#
# Датасеты в хорошем состоянии, но требуют минимальной проверки пропусков. Данные соотвествующего типа и готовы для анализа, визуализации и построения моделей предсказания увольнения сотрудников.
#
# </div>

# %% [markdown]
# ### Предобработка данных.

# %%
# Проверка наличия и подсчет дубликатов строк по столбцу 'id' датафрейма 'train_quit'
duplicate_count = train_quit['id'].duplicated().sum()
print(f"Количество дубликатов: {duplicate_count}")

# Исключаем из проверки уникальных значений первую колонку 'id'
columns_to_check = train_quit.columns[1:]

# Вывод уникальных значений в колонках датафрейма
for col in columns_to_check:
    print(f"{col}: {train_quit[col].unique()}")
# Out:
# Количество дубликатов: 0
# dept: ['sales' 'purchasing' 'marketing' 'technology' 'hr']
# level: ['middle' 'junior' 'sinior']
# workload: ['high' 'medium' 'low']
# employment_years: [ 2  5  1  8  4  7  3  9  6 10]
# last_year_promo: ['no' 'yes']
# last_year_violations: ['no' 'yes']
# supervisor_evaluation: [4 1 3 5 2]
# salary: [54000 27600 37200 24000 25200 18000 44400 19200 45600 57600 33600 16800
#  22800 26400 82800 32400 39600 30000 46800 12000 15600 58800 60000 66000
#  21600 38400 62400 40800 56400 34800 28800 52800 20400 36000 61200 48000
#  43200 73200 31200 78000 64800 72000 94800 96000 63600 79200 55200 42000
#  49200 50400 14400 13200 51600 67200 88800 68400 69600 70800 84000 81600
#  87600 75600 91200 76800 74400 80400 85200 86400 92400]
# quit: ['no' 'yes']

# %%
# Проверка наличия и подсчет дубликатов строк по столбцу 'id' датафрейма 'test_features_2')
duplicate_count = test_features_2['id'].duplicated().sum()
print(f"Количество дубликатов: {duplicate_count}")

# Исключаем из проверки уникальных значений первую колонку 'id'
columns_to_check = test_features_2.columns[1:]

# Вывод уникальных значений в колонках датафрейма
for col in columns_to_check:
    print(f"{col}: {test_features_2[col].unique()}")
# Out:
# Количество дубликатов: 0
# dept: ['marketing' 'hr' 'sales' 'purchasing' 'technology' nan ' ']
# level: ['junior' 'middle' 'sinior' nan]
# workload: ['medium' 'low' 'high' ' ']
# employment_years: [ 2  1  5  6  3  9  7  4  8 10]
# last_year_promo: ['no' 'yes']
# last_year_violations: ['no' 'yes']
# supervisor_evaluation: [5 4 3 1 2]
# salary: [28800 30000 19200 40800 42000 26400 49200 62400 14400 36000 33600 44400
#  27600 12000 64800 20400 34800 15600 18000 50400 31200 51600 16800 43200
#  52800 32400 37200 58800 24000 21600 48000 45600 25200 63600 61200 56400
#  38400 46800 55200 13200 39600 54000 57600 68400 22800 72000 81600 60000
#  66000 67200 70800 76800 79200 69600 94800 82800 80400 87600 86400 96000
#  78000 75600 73200 84000 88800 92400]

# %% [markdown]
# <div class='alert alert-info'><b>
#
# Комментарий студента:</b>
#
# Необходимо заменить в таблице пробелы ' ' пустым значениям NaN.
#
# </div>

# %%
# Замена пробелов в столбцах 'dept' и 'workload' на NaN (пропущенные значения), чтобы корректнее обрабатывать данные
test_features_2['dept'] = test_features_2['dept'].replace(' ', np.nan)
test_features_2['workload'] = test_features_2['workload'].replace(' ', np.nan)

# Вывод уникальных значений в колонках датафрейма
for col in columns_to_check:
    print(f"{col}: {test_features_2[col].unique()}")
# Out:
# dept: ['marketing' 'hr' 'sales' 'purchasing' 'technology' nan]
# level: ['junior' 'middle' 'sinior' nan]
# workload: ['medium' 'low' 'high' nan]
# employment_years: [ 2  1  5  6  3  9  7  4  8 10]
# last_year_promo: ['no' 'yes']
# last_year_violations: ['no' 'yes']
# supervisor_evaluation: [5 4 3 1 2]
# salary: [28800 30000 19200 40800 42000 26400 49200 62400 14400 36000 33600 44400
#  27600 12000 64800 20400 34800 15600 18000 50400 31200 51600 16800 43200
#  52800 32400 37200 58800 24000 21600 48000 45600 25200 63600 61200 56400
#  38400 46800 55200 13200 39600 54000 57600 68400 22800 72000 81600 60000
#  66000 67200 70800 76800 79200 69600 94800 82800 80400 87600 86400 96000
#  78000 75600 73200 84000 88800 92400]

# %%
# Проверка наличия и подсчет дубликатов строк по столбцу 'id' датафрейма 'test_target_quit'
duplicate_count = test_target_quit['id'].duplicated().sum()
print(f"Количество дубликатов: {duplicate_count}")

# Исключаем из проверки уникальных значений первую колонку 'id'
columns_to_check = test_target_quit.columns[1:]

# Вывод уникальных значений в колонках датафрейма
for col in columns_to_check:
    print(f"{col}: {test_target_quit[col].unique()}")
# Out:
# Количество дубликатов: 0
# quit: ['yes' 'no']

# %% [markdown]
# <div class='alert alert-info'><b>
#
# Комментарий студента:</b>
#
# В столбцах dept (отдел) и workload (уровень загруженности) пробелы были заменены на NaN, что корректно обозначает пропущенные данные. Это важно для последующего анализа, позволяет избежать ошибок при статистических расчетах, упрощает фильтрацию и очистку данных.
#
# В столбце id датафреймов train_quit, test_features_2 и test_target_quit дубликаты отсутствуют. Это означает, что каждая запись уникальна. А данные готовы для объединения с другими таблицами по ключу id.
#
# </div>

# %% [markdown]
# ### Исследовательский анализ данных.

# %%
'''
# Создание списка количественных столбцов датасета train_quit
num_col = ['employment_years', 
           'supervisor_evaluation', 
           'salary']

# Ппостроение распределений количественных признаков датасета train_quit
plot_columns_hist_box(train_quit, num_col)
'''
# Out:
# "\n# Создание списка количественных столбцов датасета train_quit\nnum_col = ['employment_years', \n           'supervisor_evaluation', \n           'salary']\n\n# Ппостроение распределений количественных признаков датасета train_quit\nplot_columns_hist_box(train_quit, num_col)\n"

# %%
# Разделение признаков на количественные и дискретные
continuous_columns = ['salary']
discrete_columns = ['employment_years', 'supervisor_evaluation']

# Построение графиков для количественных признаков
plot_continuous_features(train_quit, continuous_columns)

# Построение графиков для дискретных признаков
plot_discrete_features(train_quit, discrete_columns)

# %%
'''
# Создание списка количественных столбцов датасета test_features_2
num_col_1 = ['employment_years', 
           'supervisor_evaluation', 
           'salary']

# Построение распределений количественных признаков датасета test_features_2
plot_columns_hist_box(test_features_2, num_col_1)
'''
# Out:
# "\n# Создание списка количественных столбцов датасета test_features_2\nnum_col_1 = ['employment_years', \n           'supervisor_evaluation', \n           'salary']\n\n# Построение распределений количественных признаков датасета test_features_2\nplot_columns_hist_box(test_features_2, num_col_1)\n"

# %%
# Разделение признаков на количественные и дискретные
continuous_columns = ['salary']
discrete_columns = ['employment_years', 'supervisor_evaluation']

# Построение графиков для количественных признаков
plot_continuous_features(test_features_2, continuous_columns)

# Построение графиков для дискретных признаков
plot_discrete_features(test_features_2, discrete_columns)

# %% [markdown]
# <div class='alert alert-info'><b>
#
# Комментарий студента:</b>
#
# Аномальных выбросов значений нет. Данные распределены нормально, со смещением влево по признакам "Длительность работы" и "Зарплата".
#
# </div>

# %%
# Создание списка категориальных столбцов датасета train_quit
col_col_2 = ['dept', 'level',
           'workload', 'last_year_promo',
           'last_year_violations', 'quit']


# Построение круговых диаграм категориальных признаков датасета train_quit
for col in col_col_2:
    create_pie_chart(train_quit, col)

# %%
# Создание списка категориальных столбцов датасета test_features_2
col_col_2 = ['dept', 'level',
           'workload', 'last_year_promo',
           'last_year_violations']


# Построение круговых диаграм категориальных признаков датасета test_features_2
for col in col_col_2:
    create_pie_chart(test_features_2, col)

# %%
# Построение круговой диаграммы категориальных признаков датасета test_target_quit
create_pie_chart(test_target_quit, 'quit')

# %% [markdown]
# <div class='alert alert-info'><b>
#
# Комментарий студента:</b>
#
# В тренировочном и тестовом датасетах признаки имеют схожее распределение. Количество уволившихся сотрудников запоследний год достаточно высокое - 28,2%.
#
# </div>

# %%
'''
# Вычисляем корреляционную матрицу phik датасета train_quit
phik_corr_matrix = train_quit.phik_matrix()

# Преобразование индекса и столбцов корреляционной матрицы
phik_corr_matrix = phik_corr_matrix.reindex(columns=[c for c in phik_corr_matrix.columns if c != 'id'],
                                            index=[i for i in phik_corr_matrix.index if i != 'id'])

# Применение словаря для отображения названий колонок
phik_corr_matrix = phik_corr_matrix.rename(index=column_names, columns=column_names)

# Визуализация корреляционной матрицы
plt.figure(figsize=(15, 10))
sns.heatmap(phik_corr_matrix, annot=True, cmap='coolwarm', vmin=0, vmax=1)
plt.title('Корреляционная матрица (phi_K)')
plt.show()
'''
# Out:
# "\n# Вычисляем корреляционную матрицу phik датасета train_quit\nphik_corr_matrix = train_quit.phik_matrix()\n\n# Преобразование индекса и столбцов корреляционной матрицы\nphik_corr_matrix = phik_corr_matrix.reindex(columns=[c for c in phik_corr_matrix.columns if c != 'id'],\n                                            index=[i for i in phik_corr_matrix.index if i != 'id'])\n\n# Применение словаря для отображения названий колонок\nphik_corr_matrix = phik_corr_matrix.rename(index=column_names, columns=column_names)\n\n# Визуализация корреляционной матрицы\nplt.figure(figsize=(15, 10))\nsns.heatmap(phik_corr_matrix, annot=True, cmap='coolwarm', vmin=0, vmax=1)\nplt.title('Корреляционная матрица (phi_K)')\nplt.show()\n"

# %%
# Вычисляем корреляционную матрицу phik датасета train_quit
# Список непрерывных признаков
interval_cols = ['salary']

# Вычисляем корреляционную матрицу phik с явным указанием непрерывных признаков
phik_corr_matrix = test_features.phik_matrix(interval_cols=interval_cols)

# Преобразование индекса и столбцов корреляционной матрицы
phik_corr_matrix = phik_corr_matrix.reindex(columns=[c for c in phik_corr_matrix.columns if c != 'id'],
                                            index=[i for i in phik_corr_matrix.index if i != 'id'])

# Применение словаря для отображения названий колонок
phik_corr_matrix = phik_corr_matrix.rename(index=column_names, columns=column_names)

# Визуализация корреляционной матрицы
plt.figure(figsize=(15, 10))
sns.heatmap(phik_corr_matrix, annot=True, cmap='coolwarm', vmin=0, vmax=1)
plt.title('Корреляционная матрица (phi_K)')
plt.show()
# Out:
# /opt/conda/lib/python3.9/site-packages/phik/data_quality.py:59: UserWarning: The number of unique values of variable id is large: 2000. Are you sure this is not an interval variable? Analysis for pairs of variables including id can be slow.
#   warnings.warn(

# %% [markdown]
# <div class='alert alert-info'><b>
#
# Комментарий студента:</b>
#
# Наиболее значимая связь увольнения сотруднка со стажем работы в компании и уровнем зарплаты. Меньше зависимость от уровня должности и оценки работы. Нарушения и загруженность играют небольшую роль. Отдел не влияет на текучесть — проблема увольнений системная, а не локальная.
#
# </div>

# %%
'''
# Вычисляем корреляционную матрицу phik датасета test_features_2
phik_corr_matrix = test_features_2.phik_matrix()

# Преобразование индекса и столбцов корреляционной матрицы
phik_corr_matrix = phik_corr_matrix.reindex(columns=[c for c in phik_corr_matrix.columns if c != 'id'],
                                            index=[i for i in phik_corr_matrix.index if i != 'id'])

# Применение словаря для отображения названий колонок
phik_corr_matrix = phik_corr_matrix.rename(index=column_names, columns=column_names)

# Визуализация корреляционной матрицы
plt.figure(figsize=(15, 10))
sns.heatmap(phik_corr_matrix, annot=True, cmap='coolwarm', vmin=0, vmax=1)
plt.title('Корреляционная матрица (phi_K)')
plt.show()
'''
# Out:
# "\n# Вычисляем корреляционную матрицу phik датасета test_features_2\nphik_corr_matrix = test_features_2.phik_matrix()\n\n# Преобразование индекса и столбцов корреляционной матрицы\nphik_corr_matrix = phik_corr_matrix.reindex(columns=[c for c in phik_corr_matrix.columns if c != 'id'],\n                                            index=[i for i in phik_corr_matrix.index if i != 'id'])\n\n# Применение словаря для отображения названий колонок\nphik_corr_matrix = phik_corr_matrix.rename(index=column_names, columns=column_names)\n\n# Визуализация корреляционной матрицы\nplt.figure(figsize=(15, 10))\nsns.heatmap(phik_corr_matrix, annot=True, cmap='coolwarm', vmin=0, vmax=1)\nplt.title('Корреляционная матрица (phi_K)')\nplt.show()\n"

# %%
# Вычисляем корреляционную матрицу phik датасета test_features_2
# Список непрерывных признаков
interval_cols = ['salary']

# Вычисляем корреляционную матрицу phik с явным указанием непрерывных признаков
phik_corr_matrix = test_features.phik_matrix(interval_cols=interval_cols)

# Преобразование индекса и столбцов корреляционной матрицы
phik_corr_matrix = phik_corr_matrix.reindex(columns=[c for c in phik_corr_matrix.columns if c != 'id'],
                                            index=[i for i in phik_corr_matrix.index if i != 'id'])

# Применение словаря для отображения названий колонок
phik_corr_matrix = phik_corr_matrix.rename(index=column_names, columns=column_names)

# Визуализация корреляционной матрицы
plt.figure(figsize=(15, 10))
sns.heatmap(phik_corr_matrix, annot=True, cmap='coolwarm', vmin=0, vmax=1)
plt.title('Корреляционная матрица (phi_K)')
plt.show()
# Out:
# /opt/conda/lib/python3.9/site-packages/phik/data_quality.py:59: UserWarning: The number of unique values of variable id is large: 2000. Are you sure this is not an interval variable? Analysis for pairs of variables including id can be slow.
#   warnings.warn(

# %% [markdown]
# <div class='alert alert-info'><b>
#
# Комментарий студента:</b>
#
# Мультиколлинеарность признаков в тренировочном и тестовом датасетах не наблюдается.
#
# </div>

# %%
# Фильтруем данные по значению 'quit'
no_quit = train_quit[train_quit['quit'] == 'no']
yes_quit = train_quit[train_quit['quit'] == 'yes']

# Количественные признаки
num_col = ['employment_years', 'supervisor_evaluation', 'salary']

# Создаем матрицу диаграмм рассеяния
fig, axes = plt.subplots(len(num_col), len(num_col), 
                         figsize=(15, 15), 
                         facecolor='#e8f5e9')  # светло-зеленый фон

# Заполняем матрицу
for i, col1 in enumerate(num_col):
    for j, col2 in enumerate(num_col):
        ax = axes[i, j]
        
        # Диаграммы рассеяния
        if i != j:
            # Синие точки для не уволившихся (увеличенный размер точек)
            ax.scatter(no_quit[col2], no_quit[col1], 
                       c='blue', alpha=0.25, s=50, label='Не уволился')
            
            # Оранжевые точки для уволившихся (увеличенный размер точек)
            ax.scatter(yes_quit[col2], yes_quit[col1], 
                       c='orange', alpha=0.25, s=50, label='Уволился')
            
            # Увеличиваем шрифт подписей осей
            ax.set_xlabel(column_names.get(col2, col2), fontsize=12)
            ax.set_ylabel(column_names.get(col1, col1), fontsize=12)
            
            # Увеличиваем шрифт значений на осях
            ax.tick_params(axis='both', which='major', labelsize=8)
            
        else:
            # Гистограммы на диагонали
            ax.hist(train_quit[col1], bins=20, color='green', alpha=0.7)
            ax.set_title(column_names.get(col1, col1), fontsize=14)
        
        # Убираем лишние подписи
        if i < len(num_col) - 1:
            ax.set_xticks([])
        if j > 0:
            ax.set_yticks([])

# Общие настройки
plt.suptitle('Матрица диаграмм рассеяния с разметкой по увольнениям', 
             fontsize=24, fontweight="bold", color='green', y=0.98)  # Поднимаем заголовок выше
plt.tight_layout()
plt.subplots_adjust(top=0.92)  # Больше места для заголовка

# Легенда (выносим в отдельный subplot)
handles = [
    plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='blue', markersize=10),
    plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='orange', markersize=10)
]
fig.legend(handles, ['Не уволился', 'Уволился'], 
           loc='lower right', bbox_to_anchor=(0.95, 0.10))

plt.show()

# %% [markdown]
# #### Портрет «уволившегося сотрудника».

# %%
# 1. Процент уволившихся по отделам
# Группируем данные по столбцу 'dept' и считаем количество 'yes' в столбце 'quit'
quit_by_dept = train_quit.groupby('dept')['quit'].value_counts(normalize=True).unstack().fillna(0)
quit_by_dept['percent_quit'] = quit_by_dept['yes'] * 100  # переводим в проценты

# Выводим результат
print("Доля уволившихся за последний год от числа сотрудников конкретного отдела:")
display(quit_by_dept[['percent_quit']])

# 2. Средняя зарплата уволившихся и оставшихся сотрудников
# Разделяем данные на две группы: уволившиеся ('yes') и оставшиеся ('no')
salary_by_quit_status = train_quit.groupby('quit')['salary'].mean()

# Выводим результат
print("Средняя зарплата уволившихся и оставшихся сотрудников:")
display(salary_by_quit_status)

# Дополнительно: Средняя зарплата по каждому отделу для уволившихся и оставшихся
salary_by_dept_and_quit = train_quit.groupby(['dept', 'quit'])['salary'].mean().unstack()
print("Средняя зарплата по отделам для уволившихся и оставшихся сотрудников:")
display(salary_by_dept_and_quit)
# Out:
# Доля уволившихся за последний год от числа сотрудников конкретного отдела:
# quit        percent_quit
# dept
# hr             25.000000
# marketing      28.006873
# purchasing     28.231293
# sales          28.303199
# technology     29.741379
# Средняя зарплата уволившихся и оставшихся сотрудников:
# quit
# no     37702.228412
# yes    23885.106383
# Name: salary, dtype: float64
# Средняя зарплата по отделам для уволившихся и оставшихся сотрудников:
# quit                  no           yes
# dept
# hr          37324.137931  22520.689655
# marketing   39161.813842  24058.895706
# purchasing  35840.758294  23378.313253
# sales       35278.370514  21832.923833
# technology  42003.680982  27686.956522

# %%
'''
# Распределение общего числа уволившихся по отделам
# Считаем общее количество уволившихся ('yes') по каждому отделу
total_quit_by_dept = train_quit[train_quit['quit'] == 'yes'].groupby('dept').size()

# Вычисляем доли уволившихся по отделам в процентах
total_quit_percentage = total_quit_by_dept / total_quit_by_dept.sum() * 100

# Форматируем значения с двумя знаками после запятой и добавляем значок %
total_quit_percentage_formatted = total_quit_percentage.map("{:.2f}%".format)

# Выводим результат
print("Распределение общего числа уволившихся по отделам в процентах (сумма = 100%):")
display(total_quit_percentage_formatted)
'''
# Out:
# '\n# Распределение общего числа уволившихся по отделам\n# Считаем общее количество уволившихся (\'yes\') по каждому отделу\ntotal_quit_by_dept = train_quit[train_quit[\'quit\'] == \'yes\'].groupby(\'dept\').size()\n\n# Вычисляем доли уволившихся по отделам в процентах\ntotal_quit_percentage = total_quit_by_dept / total_quit_by_dept.sum() * 100\n\n# Форматируем значения с двумя знаками после запятой и добавляем значок %\ntotal_quit_percentage_formatted = total_quit_percentage.map("{:.2f}%".format)\n\n# Выводим результат\nprint("Распределение общего числа уволившихся по отделам в процентах (сумма = 100%):")\ndisplay(total_quit_percentage_formatted)\n'

# %% [markdown]
# <div class='alert alert-info'><b>
#
# Комментарий студента:</b>
#
# "Портрет" уволившихся сотрудников:
#
# - Junior с низкой зарплатой (до 28 000) и стажем менее 3 лет.
#
# - Отсутствие повышений за последний год.
#
# - Высокая нагрузка.
#
# - Низкая оценка руководителя (≤3) или нарушения.
#
# - Работа в стрессовых отделах (продажи, технологии).
#
# Возможные причины увольнений: низкая зарплата, отсутствие повышений, высокая рабочая нагрузка без компенсации. Также на увольнения влияют низкие оценки и дисциплинарные проблемы.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Проанализирован портрет уволившегося сотрудника. Молодец, что используешь относительные величины для анализа категориальных признаков, а также сравниваешь средние по `salary`.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# 1. С помощью относительных величин нужно исследовать все признаки, кроме `salary`.
# 2. Проверь корректность расчёта относительных величин - сумма долей по `yes` должна давать 100%.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Тут актуально по обоим пунктам. Для правильного расчёта доли можно использовать подход с `value_counts(normalize=True)`:
#
# 1. Для начала делаем срез по `train` со значениями `yes`:
#
#
#     df = train[train['quit'] == 'yes']
#
#
# 2. Далее, выбирая каждый признак выборки, кроме `salary`, применяем описанный выше метод:
#
#
#     df[col].value_counts(normalize=True)
#
#
# Получившуюся таблицу по желанию можно визуализировать с помощью графика типа `bar` или `countplot`.

# %% [markdown]
# <div class='alert alert-info'><b>
#
# Комментарий студента 3:</b>
#
# 1. С помощью относительных величин исследуем все признаки train_quit, кроме salary.
#
# 2. Вычисляем распределение общего числа уволившихся по отделам в процентах (сумма = 100%)
#
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
# Создаем срез данных для quit == 'yes'
df_yes = train_quit[train_quit['quit'] == 'yes']

# Проверяем, есть ли данные в срезе
if df_yes.empty:
    raise ValueError("Срез данных для quit == 'yes' пуст. Проверьте данные.")

# Список признаков для анализа (исключаем 'id', 'salary' и 'quit')
features_to_analyze = ['dept', 'level', 'workload', 'employment_years', 
                       'last_year_promo', 'last_year_violations', 'supervisor_evaluation']

# Создаем словарь для хранения результатов
relative_frequencies = {}

# Вычисляем относительные частоты для каждого признака
for col in features_to_analyze:
    # Проверяем, есть ли значения в текущем признаке
    if df_yes[col].isnull().all():
        print(f"Признак '{col}' содержит только пропущенные значения.")
        relative_frequencies[col] = None  # Пропускаем этот признак
        continue
    
    # Вычисляем относительные частоты
    freq = df_yes[col].value_counts(normalize=True).sort_index()
    if freq.empty:
        print(f"Признак '{col}' не содержит значений после фильтрации.")
        relative_frequencies[col] = None  # Пропускаем этот признак
        continue
    
    relative_frequencies[col] = freq

# Преобразуем словарь в DataFrame для удобства просмотра
relative_frequencies_df = pd.DataFrame(relative_frequencies)

# Настройка графиков
plt.figure(figsize=(15, 10))

# Рисуем график для каждого признака
for i, col in enumerate(features_to_analyze, 1):
    if relative_frequencies[col] is None:
        continue  # Пропускаем признаки без данных
    
    plt.subplot(3, 3, i)  # 3x3 сетка для графиков
    sns.barplot(x=relative_frequencies[col].index, y=relative_frequencies[col].values)
    plt.title(f'Относительная частота для {column_names.get(col, col)}')
    plt.xlabel(column_names.get(col, col))  # Подпись оси X
    plt.ylabel('Относительная частота')      # Подпись оси Y

plt.tight_layout()
plt.show()

# %%
# Создаем срез данных для quit == 'yes'
df_yes = train_quit[train_quit['quit'] == 'yes']

# Вычисляем доли уволившихся по отделам с помощью value_counts(normalize=True)
quit_percentage_by_dept = df_yes['dept'].value_counts(normalize=True) * 100

# Форматируем значения с двумя знаками после запятой и добавляем значок %
quit_percentage_by_dept_formatted = quit_percentage_by_dept.map("{:.2f}%".format)

# Выводим результат
print("Распределение общего числа уволившихся по отделам в процентах (сумма = 100%):")
display(quit_percentage_by_dept_formatted)

plt.figure(figsize=(8, 6))
quit_percentage_by_dept.plot(kind='bar', color='skyblue')
plt.title('Распределение уволившихся по отделам')
plt.xlabel('Отдел')
plt.ylabel('Процент уволившихся')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Распределение общего числа уволившихся по отделам в процентах (сумма = 100%):
# sales         36.08%
# technology    24.47%
# purchasing    14.72%
# marketing     14.45%
# hr            10.28%
# Name: dept, dtype: object

# %%
### Добавление нового входного признака

# %%
'''
# Добавляем новый столбец 'job_satisfaction_rate' с предсказаниями лучшей модели из задания 2
train_quit['job_satisfaction_rate'] = best_model.predict(train_quit)

# Сортируем данные по столбцу 'id' в порядке возрастания
train_quit.sort_values(by='id', ascending=True, inplace=True)

# Проверяем результат
train_quit.head()
'''
# Out:
# "\n# Добавляем новый столбец 'job_satisfaction_rate' с предсказаниями лучшей модели из задания 2\ntrain_quit['job_satisfaction_rate'] = best_model.predict(train_quit)\n\n# Сортируем данные по столбцу 'id' в порядке возрастания\ntrain_quit.sort_values(by='id', ascending=True, inplace=True)\n\n# Проверяем результат\ntrain_quit.head()\n"

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Действие выполнено преждевременно - мы сначала выполняем задание `3.3` на реальных данных, чтобы по итогу анализа принять решение о том, стоит ли добавлять признак в выборку. Поэтому сначала проводим исследование распределения, а уже потом, если решаем, что признак важен - добавляем в выборки.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# #### Проверка на тестовых данных, что уровень удовлетворённости сотрудника работой в компании влияет на увольнение

# %%
'''
# Настройка стиля графиков
sns.set(style="whitegrid")

# 1. График распределения коэффициента удовлетворенности работой уволенных и оставшихся сотрудников
plt.figure(figsize=(10, 6))
sns.histplot(
    data=train_quit,
    x='job_satisfaction_rate',
    hue='quit',
    kde=True,
    bins=30,
    palette=['blue', 'darkorange']  # Установлены цвета для групп
)
plt.title('Распределение коэффициента удовлетворенности работой уволенных и оставшихся сотрудников', fontsize=16)
plt.xlabel('Коэффициент удовлетворенности работой', fontsize=12)
plt.ylabel('Частота', fontsize=12)

# Настройка легенды
handles = [
    plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='blue', markersize=8, label='Остались'),
    plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='darkorange', markersize=8, label='Уволились')
]
plt.legend(handles=handles, title='Статус', loc='upper right')
plt.show()

# 2. Соотношение среднего коэффициента удовлетворенности ушедших сотрудников с теми, кто остался в компании
mean_satisfaction = train_quit.groupby('quit')['job_satisfaction_rate'].mean().reset_index()
mean_satisfaction['quit'] = mean_satisfaction['quit'].map({'no': 'Остались', 'yes': 'Уволились'})

plt.figure(figsize=(10, 7))
barplot = sns.barplot(
    data=mean_satisfaction,
    x='quit',
    y='job_satisfaction_rate',
    palette=['blue', 'darkorange']  # Цвета для столбцов
)

# Настройка заголовка и меток осей
plt.title('Средний коэффициент удовлетворенности ушедших и оставшихся сотрудников', fontsize=16)
plt.xlabel('Статус', fontsize=12)
plt.ylabel('Средний коэффициент удовлетворенности', fontsize=12)
plt.ylim(0, mean_satisfaction['job_satisfaction_rate'].max() + 0.1)  # Увеличиваем верхнюю границу оси Y
plt.show()

# 3. Распределение коэффициента удовлетворенности работой от уровня заработной платы
plt.figure(figsize=(12, 8))
sns.scatterplot(
    data=train_quit,
    x='salary',
    y='job_satisfaction_rate',
    hue='quit',
    palette=['navy', 'darkorange'],  # Цвета для точек
    s=80,
    alpha=0.9,
    edgecolor='black',
    linewidth=0.5,
    x_jitter=0.1  # Случайное смещение по оси X
)
plt.title('Распределение коэффициента удовлетворенности работой от уровня заработной платы', fontsize=16)
plt.xlabel('Заработная плата', fontsize=12)
plt.ylabel('Коэффициент удовлетворенности работой', fontsize=12)

# Настройка легенды
handles = [
    plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='navy', markersize=8, label='Остались'),
    plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='darkorange', markersize=8, label='Уволились')
]
plt.legend(handles=handles, title='Статус', loc='lower right')  # Легенда в нижнем правом углу
plt.show()
'''
# Out:
# '\n# Настройка стиля графиков\nsns.set(style="whitegrid")\n\n# 1. График распределения коэффициента удовлетворенности работой уволенных и оставшихся сотрудников\nplt.figure(figsize=(10, 6))\nsns.histplot(\n    data=train_quit,\n    x=\'job_satisfaction_rate\',\n    hue=\'quit\',\n    kde=True,\n    bins=30,\n    palette=[\'blue\', \'darkorange\']  # Установлены цвета для групп\n)\nplt.title(\'Распределение коэффициента удовлетворенности работой уволенных и оставшихся сотрудников\', fontsize=16)\nplt.xlabel(\'Коэффициент удовлетворенности работой\', fontsize=12)\nplt.ylabel(\'Частота\', fontsize=12)\n\n# Настройка легенды\nhandles = [\n    plt.Line2D([0], [0], marker=\'o\', color=\'w\', markerfacecolor=\'blue\', markersize=8, label=\'Остались\'),\n    plt.Line2D([0], [0], marker=\'o\', color=\'w\', markerfacecolor=\'darkorange\', markersize=8, label=\'Уволились\')\n]\nplt.legend(handles=handles, title=\'Статус\', loc=\'upper right\')\nplt.show()\n\n# 2. Соотношение среднего коэффициен
# ...

# %%
# Настройка стиля графиков
sns.set(style="whitegrid")

# 1. Объединение тестовых данных с целевыми признаками
# Сначала объединяем test_features_2 с test_target_job_satisfaction_rate
test_data = test_features_2.merge(test_target_job_satisfaction_rate[['id', 'job_satisfaction_rate']], on='id', how='left')

# Затем добавляем 'quit' из test_target_quit
test_data = test_data.merge(test_target_quit[['id', 'quit']], on='id', how='left')

# 2. График распределения коэффициента удовлетворенности работой уволенных и оставшихся сотрудников
plt.figure(figsize=(10, 6))
sns.histplot(
    data=test_data,
    x='job_satisfaction_rate',
    hue='quit',
    stat='density',  # Нормированная гистограмма
    common_norm=False,  # Раздельная нормировка для каждой группы
    kde=True,  # Добавление KDE-графика
    bins=30,
    palette=['blue', 'darkorange']  # Цвета для групп
)
plt.title('Распределение коэффициента удовлетворенности работой уволенных и оставшихся сотрудников', fontsize=16)
plt.xlabel('Коэффициент удовлетворенности работой', fontsize=12)
plt.ylabel('Плотность распределения', fontsize=12)

# Настройка легенды
handles = [
    plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='blue', markersize=8, label='Остались'),
    plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='darkorange', markersize=8, label='Уволились')
]
plt.legend(handles=handles, title='Статус', loc='upper right')
plt.show()

# 3. Соотношение среднего коэффициента удовлетворенности ушедших сотрудников с теми, кто остался в компании
mean_satisfaction = test_data.groupby('quit')['job_satisfaction_rate'].mean().reset_index()
mean_satisfaction['quit'] = mean_satisfaction['quit'].map({'no': 'Остались', 'yes': 'Уволились'})

plt.figure(figsize=(10, 7))
barplot = sns.barplot(
    data=mean_satisfaction,
    x='quit',
    y='job_satisfaction_rate',
    palette=['blue', 'darkorange']  # Цвета для столбцов
)

# Настройка заголовка и меток осей
plt.title('Средний коэффициент удовлетворенности ушедших и оставшихся сотрудников', fontsize=16)
plt.xlabel('Статус', fontsize=12)
plt.ylabel('Средний коэффициент удовлетворенности', fontsize=12)
plt.ylim(0, mean_satisfaction['job_satisfaction_rate'].max() + 0.1)  # Увеличиваем верхнюю границу оси Y
plt.show()

# 4. Распределение коэффициента удовлетворенности работой от уровня заработной платы
plt.figure(figsize=(12, 8))
sns.scatterplot(
    data=test_data,
    x='salary',
    y='job_satisfaction_rate',
    hue='quit',
    palette=['navy', 'darkorange'],  # Цвета для точек
    s=80,
    alpha=0.9,
    edgecolor='black',
    linewidth=0.5,
    x_jitter=0.1  # Случайное смещение по оси X
)
plt.title('Распределение коэффициента удовлетворенности работой от уровня заработной платы', fontsize=16)
plt.xlabel('Заработная плата', fontsize=12)
plt.ylabel('Коэффициент удовлетворенности работой', fontsize=12)

# Настройка легенды
handles = [
    plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='navy', markersize=8, label='Остались'),
    plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='darkorange', markersize=8, label='Уволились')
]
plt.legend(handles=handles, title='Статус', loc='lower right')  # Легенда в нижнем правом углу
plt.show()

# %% [markdown]
# <div class='alert alert-info'><b>
#
# Комментарий студента 2:</b>
#
# Формулировка гипотез:
#
# 1. Нулевая гипотеза H0: Распределения коэффициента удовлетворенности работой (job_satisfaction_rate) для уволившихся и оставшихся сотрудников одинаковы.
#
# 2. Альтернативная гипотеза H1: Распределения коэффициента удовлетворенности работой для уволившихся и оставшихся сотрудников различны.</div>

# %%
# from scipy.stats import ttest_ind, mannwhitneyu, shapiro, levene

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
# Все библиотеки стоит импортировать в начале проекта - таким образом получатель твоего отчёта сможет узнать о проблемах с его окружением сразу перед работой с проектом, а не посреди или в конце проекта.

# %%
# Настройка стиля графиков
sns.set(style="whitegrid")

# 1. Объединение тестовых данных с целевыми признаками
# Сначала объединяем test_features_2 с test_target_job_satisfaction_rate
test_data = test_features_2.merge(test_target_job_satisfaction_rate[['id', 'job_satisfaction_rate']], on='id', how='left')

# Затем добавляем 'quit' из test_target_quit
test_data = test_data.merge(test_target_quit[['id', 'quit']], on='id', how='left')

# Разделение данных на две группы
satisfaction_quit = test_data[test_data['quit'] == 'yes']['job_satisfaction_rate']  # Уволились
satisfaction_stay = test_data[test_data['quit'] == 'no']['job_satisfaction_rate']   # Остались

# 2. График распределения коэффициента удовлетворенности работой уволенных и оставшихся сотрудников
plt.figure(figsize=(10, 6))
sns.histplot(
    data=test_data,
    x='job_satisfaction_rate',
    hue='quit',
    stat='density',
    common_norm=False,
    kde=True,
    bins=30,
    palette=['blue', 'darkorange']
)
plt.title('Распределение коэффициента удовлетворенности работой уволенных и оставшихся сотрудников', fontsize=16)
plt.xlabel('Коэффициент удовлетворенности работой', fontsize=12)
plt.ylabel('Плотность распределения', fontsize=12)
plt.legend(title='Статус', loc='upper right')
plt.show()

# 3. Проверка нормальности распределения
shapiro_quit = shapiro(satisfaction_quit)
shapiro_stay = shapiro(satisfaction_stay)

print("Тест Шапиро-Уилка для группы 'уволились':")
print(f"p-value: {shapiro_quit.pvalue:.4f}, {'Нормальное распределение' if shapiro_quit.pvalue > 0.05 else 'Ненормальное распределение'}\n")

print("Тест Шапиро-Уилка для группы 'остались':")
print(f"p-value: {shapiro_stay.pvalue:.4f}, {'Нормальное распределение' if shapiro_stay.pvalue > 0.05 else 'Ненормальное распределение'}\n")

# 4. Проверка однородности дисперсий
levene_test = levene(satisfaction_quit, satisfaction_stay)
print("Тест Левена для однородности дисперсий:")
print(f"p-value: {levene_test.pvalue:.4f}, {'Однородные дисперсии' if levene_test.pvalue > 0.05 else 'Неоднородные дисперсии'}\n")

# 5. Проведение статистического теста
if shapiro_quit.pvalue > 0.05 and shapiro_stay.pvalue > 0.05 and levene_test.pvalue > 0.05:
    # Если распределения нормальные и дисперсии однородны, используем t-тест
    test_result = ttest_ind(satisfaction_quit, satisfaction_stay, equal_var=True)
    test_name = "t-тест"
else:
    # В противном случае используем тест Манна-Уитни
    test_result = mannwhitneyu(satisfaction_quit, satisfaction_stay)
    test_name = "Тест Манна-Уитни"

# Вывод результатов теста
print(f"{test_name} для сравнения распределений:")
print(f"p-value: {test_result.pvalue:.4f}")
if test_result.pvalue < 0.05:
    print("Различия между распределениями статистически значимы.")
else:
    print("Нет статистически значимых различий между распределениями.")
# Out:
# No handles with labels found to put in legend.
# Тест Шапиро-Уилка для группы 'уволились':
# p-value: 0.0000, Ненормальное распределение
#
# Тест Шапиро-Уилка для группы 'остались':
# p-value: 0.0000, Ненормальное распределение
#
# Тест Левена для однородности дисперсий:
# p-value: 0.2293, Однородные дисперсии
#
# Тест Манна-Уитни для сравнения распределений:
# p-value: 0.0000
# Различия между распределениями статистически значимы.

# %% [markdown]
# <div class='alert alert-info'><b>
#
# Комментарий студента:</b>
#
# Уровень удовлетворенности сотрудников влияет на увольнение. Коэффициент удовлетворенности оставшихся сотрудников - 0,61, а уволившихся - 0,39. Различия между распределениями статистически значимы.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# 1. Анализ должен быть выполнен по `test` выборке (см.условие проекта) - для этого по `id` в новую выборку нужно соединить целевые признаки обеих задач.
#
# 2. Анализ должен быть выполнен по реальным, а не предсказанным значениям: реальные значения мы можем использовать для анализа исторических данных, так как они содержат важные паттерны для анализа зависимостей, которые также запоминает и модель, но чтобы иметь возможность работать с новыми работниками без исторических данных, модель должна использовать признак на основе предсказаний.
#
# 3. Здесь мы имеем дело с непрерывной величиной - для анализа её распределения стоит использовать нормированную гистограмму (например, `shs.histplot()` с параметрами `stat='density', common_norm=False` или `sns.kdeplot()`): гистограммы такого типа позволяют нивелировать разницу в размерах выборок при анализе распределений. Обрати также внимание, что при использовании нормированных гистограмм по оси Y будет уже не частота значений, а плотность распределения.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Чуть более интересным решением, позволяющим выполнить оценку не "на глаз", а более статистически достоверно, было бы использование статистического теста (например, `ttest`) для сравнения распределений в выборках.
#
# При этом не забывай, что при проведении статистических тестов обязательно нужно формулировать гипотезы - нулевую и альтернативную.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ### Подготовка данных в пайплайне

# %%
# Замена значений в столбце 'quit' на бинарные признаки: 1 для 'yes', 0 для 'no'
# train_quit['quit'] = train_quit['quit'].map({'yes': 1, 'no': 0})

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Кодирование нельзя делать руками:
# - при появлении новых значений категориальных признаков, не предусмотренных твоим решением, модель или упадёт, или будет генерировать ошибки;
# - такое решение не сделаешь частью `Pipeline`, а все современные решения базируются на них.
#
# Поэтому кодирование нужно делать только с применением обучаемых трансформеров. Для кодирования целевого признака нужно использовать `LabelEncoder` (https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html).

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Не учтено ниже для `test`.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
# Создаем экземпляр LabelEncoder
label_encoder = LabelEncoder()

# Кодируем столбец 'quit' с помощью LabelEncoder
train_quit['quit'] = label_encoder.fit_transform(train_quit['quit'])

# Вывод первых строк DataFrame для проверки изменений
display(train_quit.head())

# Вычисление статистических характеристик числовых столбцов, исключая столбец 'id'
train_quit[train_quit.columns[train_quit.columns != 'id']].describe()
# Out:
#        id        dept   level workload  employment_years last_year_promo  \
# 0  723290       sales  middle     high                 2              no
# 1  814010       sales  junior   medium                 2              no
# 2  155091  purchasing  middle   medium                 5              no
# 3  257132       sales  junior   medium                 2              no
# 4  910140   marketing  junior   medium                 2              no
#
#   last_year_violations  supervisor_evaluation  salary  quit
# 0                   no                      4   54000     0
# 1                   no                      4   27600     0
# 2                   no                      1   37200     0
# 3                  yes                      3   24000     1
# 4                   no                      5   25200     0
#        employment_years  supervisor_evaluation        salary        quit
# count       4000.000000            4000.000000   4000.000000  4000.00000
# ...

# %%
# Вывод первых строк DataFrame для проверки изменений
display(train_quit.head())

# Вычисление статистических характеристик числовых столбцов, исключая столбец 'id'
train_quit[train_quit.columns[train_quit.columns != 'id']].describe()
# Out:
#        id        dept   level workload  employment_years last_year_promo  \
# 0  723290       sales  middle     high                 2              no
# 1  814010       sales  junior   medium                 2              no
# 2  155091  purchasing  middle   medium                 5              no
# 3  257132       sales  junior   medium                 2              no
# 4  910140   marketing  junior   medium                 2              no
#
#   last_year_violations  supervisor_evaluation  salary  quit
# 0                   no                      4   54000     0
# 1                   no                      4   27600     0
# 2                   no                      1   37200     0
# 3                  yes                      3   24000     1
# 4                   no                      5   25200     0
#        employment_years  supervisor_evaluation        salary        quit
# count       4000.000000            4000.000000   4000.000000  4000.00000
# ...

# %%
# Добавляем новый столбец 'job_satisfaction_rate' в test_features_2, используя предсказания лучшей модели из задачи 1
test_features_2['job_satisfaction_rate'] = best_model.predict(test_features_2)

# Вычисляем статистические характеристики для числовых столбцов, исключая столбец 'id'
display(test_features_2[test_features_2.columns[test_features_2.columns != 'id']].describe())

# Выводим первые строки test_features_2 для проверки добавленного столбца
test_features_2.head()
# Out:
#        employment_years  supervisor_evaluation        salary  \
# count       2000.000000            2000.000000   2000.000000
# mean           3.666500               3.526500  34066.800000
# std            2.537222               0.996892  15398.436729
# min            1.000000               1.000000  12000.000000
# 25%            1.000000               3.000000  22800.000000
# 50%            3.000000               4.000000  30000.000000
# 75%            6.000000               4.000000  43200.000000
# max           10.000000               5.000000  96000.000000
#
#        job_satisfaction_rate
# count            2000.000000
# mean                0.552647
# std                 0.218278
# min                 0.040000
# 25%                 0.363750
# 50%                 0.594167
# 75%                 0.713333
# max                 1.000000
#        id       dept   level workload  employment_years last_year_promo  \
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В выборки добавлен новый признак на основе предсказаний модели из предыдущей задачи.

# %%
# Объединяем test_target_quit (целевые значения) с test_features_2 (признаки) по столбцу 'id'(left join)
target_features_2 = test_target_quit.merge(test_features_2, on='id', how='left')

# Перемещаем столбец 'quit' в предпоследнюю позицию
columns = target_features_2.columns.tolist()  # Получаем список всех столбцов
if 'quit' in columns:  # Проверяем, что столбец 'quit' существует
    columns.remove('quit')  # Удаляем 'quit' из списка
    columns.insert(-1, 'quit')  # Вставляем 'quit' предпоследним

# Кодируем столбец 'quit' с помощью LabelEncoder
target_features_2['quit'] = label_encoder.transform(target_features_2['quit'])

# Вывод первых строк DataFrame для проверки изменений
display(target_features_2.head())

# Вычисление статистических характеристик числовых столбцов, исключая столбец 'id'
target_features_2[target_features_2.columns[target_features_2.columns != 'id']].describe()
# Out:
#        id  quit        dept   level workload  employment_years  \
# 0  999029     1  technology  junior   medium                 1
# 1  372846     0       sales  middle   medium                10
# 2  726767     0   marketing  middle      low                 7
# 3  490105     0  purchasing  middle      low                 7
# 4  416898     1  purchasing  junior      low                 1
#
#   last_year_promo last_year_violations  supervisor_evaluation  salary  \
# 0              no                   no                      3   31200
# 1              no                  yes                      2   32400
# 2              no                   no                      4   20400
# 3              no                   no                      4   19200
# 4              no                   no                      4   12000
#
#    job_satisfaction_rate
# 0                  0.335
# 1                  0.220
# 2                  0.670
# 3                  0.695
# 4                  0.510
# ...

# %%
# Добавляем новый столбец 'job_satisfaction_rate' в train_quit, используя предсказания лучшей модели из задачи 1
train_quit['job_satisfaction_rate'] = best_model.predict(train_quit)

# Удаляем столбец 'id' из train_quit, так как он не несет полезной информации для моделирования
train_pl = train_quit.drop(['id'], axis=1)

# Вывод первых строк DataFrame для проверки изменений
display(train_pl.head())

# Проверяем наличие дубликатов в train_pl
duplicate_count = train_pl.duplicated().sum()
print(f"Количество дубликатов в данных: {duplicate_count}")

# Удаляем дубликаты строк в train_pl, чтобы избежать переобучения модели на повторяющихся данных
train_pl.drop_duplicates(inplace=True)

# Выводим информацию о размере данных после обработки
print(f"Размер данных после обработки: {train_pl.shape}")
# Out:
#          dept   level workload  employment_years last_year_promo  \
# 0       sales  middle     high                 2              no
# 1       sales  junior   medium                 2              no
# 2  purchasing  middle   medium                 5              no
# 3       sales  junior   medium                 2              no
# 4   marketing  junior   medium                 2              no
#
#   last_year_violations  supervisor_evaluation  salary  quit  \
# 0                   no                      4   54000     0
# 1                   no                      4   27600     0
# 2                   no                      1   37200     0
# 3                  yes                      3   24000     1
# 4                   no                      5   25200     0
#
#    job_satisfaction_rate
# 0               0.648000
# 1               0.842424
# 2               0.350000
# 3               0.358571
# 4               0.797857
# Количество дубликатов в данных: 1413
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Аналогично стоит проверить дубликаты перед удалением.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
# Разделяем данные на признаки (X_train) и целевую переменную (y_train)
X_train = train_pl.drop('quit', axis=1)  # Признаки: все столбцы, кроме 'quit'
y_train = train_pl['quit']  # Целевая переменная: столбец 'quit'

# Разделяем тестовые данные на признаки (X_test) и целевую переменную (y_test)
X_test = target_features_2.drop(['quit', 'id'], axis=1)  # Удаляем 'quit' и 'id' из тестовых признаков
y_test = target_features_2['quit']  # Целевая переменная: столбец 'quit'

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> В сформированных `X_train` и `X_test` отсутствует спрогнозированный `job_satisfaction_rate`. Также не очень понятно, зачем мы делаем выравнивае столбцов - при правильной подготовке данных никакое выравнивание не требуется.

# %% [markdown]
# <div class='alert alert-info'><b>
#
# Комментарий студента 3:</b>
#
# Для кодирования целевого признака 'quit' тестового датасета использон LabelEncoder. Добавлен новый столбец 'job_satisfaction_rate' в train_quit, с использованием предсказания лучшей модели из задачи 1. Удален столбец 'id' из train_quit, так как он не несет полезной информации для моделирования. полученный датасет сохранен в train_pl. Удалены дубликаты строк в train_pl, чтобы избежать переобучения модели на повторяющихся данных.</div>

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
# Определяем категории столбцов для последующей предобработки
ohe_columns = ['dept', 'last_year_promo', 'last_year_violations']  # Столбцы для OneHotEncoding
ord_columns = ['level', 'workload']  # Столбцы для OrdinalEncoding
num_columns = ['employment_years', 'supervisor_evaluation', 'salary', 'job_satisfaction_rate']  # Числовые столбцы

# Фильтрация столбцов, чтобы убрать несуществующие
ohe_columns = [col for col in ohe_columns if col in X_train.columns]
ord_columns = [col for col in ord_columns if col in X_train.columns]
num_columns = [col for col in num_columns if col in X_train.columns]

# Создаем pipeline для обработки категориальных признаков методом OneHotEncoding, заполняем пропуски наиболее частым значением
ohe_pipe = Pipeline(
    [
        ('simpleImputer_ohe', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),  
        ('ohe', OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False))  # Применяем OneHotEncoding
    ]
)

# Создаем pipeline для обработки порядковых признаков методом OrdinalEncoding, заполняем пропуски наиболее частым значением
ord_pipe = Pipeline(
    [
        ('simpleImputer_before_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent')), 
        ('ord', OrdinalEncoder(
            categories=[
                ['junior', 'middle', 'sinior'],  # Категории для столбца 'level'
                ['low', 'medium', 'high']  # Категории для столбца 'workload'
            ],
            handle_unknown='use_encoded_value', unknown_value=np.nan  # Обработка неизвестных значений
        )),
        ('simpleImputer_after_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent'))  # Заполняем пропуски
    ]
)

# Создаем ColumnTransformer для объединения всех этапов предобработки
data_preprocessor = ColumnTransformer(
    [
        ('ohe', ohe_pipe, ohe_columns),  # Применяем OneHotEncoding к ohe_columns
        ('ord', ord_pipe, ord_columns),  # Применяем OrdinalEncoding к ord_columns
        ('num', StandardScaler(), num_columns)  # Масштабируем числовые признаки
    ],
    remainder='passthrough'  # Пропускаем остальные столбцы без изменений
)

# Создаем финальный pipeline, который объединяет предобработку данных и модель машинного обучения
pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),  # Шаг предобработки данных
    ('models', DecisionTreeClassifier(random_state=RANDOM_STATE))  # Модель классификации: дерево решений
])

# %% [markdown]
# <div class='alert alert-info'><b>
#
# Комментарий студента:</b>
#
# Произведена подготовка данных и создание pipeline для обучения модели классификации.
#
# Основные этапы: предобработка данных (заполнение пропусков, кодирование категориальных признаков, масштабирование числовых) и объединение этих шагов с моделью машинного обучения.
#
# После создания pipeline модель будет обучена на тренировочных данных, с оценкой качества на тестовых.
#
#
# </div>

# %% [markdown]
# ### Обучение трех моделей с подбором гиперпараметров

# %%
# Определяем сетку гиперпараметров для перебора в GridSearchCV
param_grid = [
    {
        'models': [RandomForestClassifier(random_state=RANDOM_STATE)],
        'models__n_estimators': [50, 100, 200],
        'models__max_depth': [5, 10, 15],
        'models__min_samples_split': [2, 5, 10]
    },
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': [5, 10, 15],
        'models__min_samples_split': [2, 5, 10],
        'models__min_samples_leaf': [1, 2, 4]
    },
    {
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': [3, 5, 10],
        'models__weights': ['uniform', 'distance'],
        'models__p': [1, 2]
    }
]

# Создаем объект GridSearchCV для поиска оптимальных гиперпараметров
grid_search = GridSearchCV(
    pipe_final,  # Финальный pipeline с предобработкой и моделью
    param_grid,  # Сетка гиперпараметров для перебора
    n_jobs=-1,  # Использование всех доступных ядер процессора
    cv=5,  # Количество фолдов для кросс-валидации
    scoring='roc_auc'  # Метрика качества: ROC-AUC
)

# Обучение GridSearchCV
grid_search.fit(X_train, y_train)  # Поиск лучших параметров на тренировочных данных

# Вывод названия лучшей модели и её параметров
best_model_name = grid_search.best_estimator_.named_steps['models'].__class__.__name__  # Название лучшей модели
best_params = grid_search.best_params_  # Лучшие параметры модели

print(f"Лучшая модель: {best_model_name}")  # Вывод названия лучшей модели
print("Параметры:")  # Заголовок для вывода параметров
for param, value in best_params.items():  # Перебор всех найденных параметров
    print(f"- {param}: {value}")  # Вывод каждого параметра и его значения

# Вывод метрики ROC-AUC на кросс-валидации
print(f"\nROC-AUC на кросс-валидации: {grid_search.best_score_:.4f}")
# Out:
# Лучшая модель: RandomForestClassifier
# Параметры:
# - models: RandomForestClassifier(random_state=42)
# - models__max_depth: 5
# - models__min_samples_split: 2
# - models__n_estimators: 200
#
# ROC-AUC на кросс-валидации: 0.9192

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Найдена лучшая модель.

# %%
# Вычисление ROC-AUC на тестовых данных
# from sklearn.metrics import roc_auc_score

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
# Все библиотеки стоит импортировать в начале проекта - таким образом получатель твоего отчёта сможет узнать о проблемах с его окружением сразу перед работой с проектом, а не посреди или в конце проекта.

# %%
# Предсказываем вероятности классов для тестовых данных
y_test_proba = grid_search.best_estimator_.predict_proba(X_test)[:, 1]  # Вероятности класса "1"
roc_auc_test = roc_auc_score(y_test, y_test_proba)  # Вычисляем ROC-AUC
print(f"ROC-AUC на тестовых данных: {roc_auc_test:.4f}")
# Out:
# ROC-AUC на тестовых данных: 0.9227

# %%
# Создание и обучение DummyClassifier
dummy_model = DummyClassifier(strategy='most_frequent', random_state=RANDOM_STATE)  # Предсказывает наиболее частый класс
dummy_model.fit(X_train, y_train)

# Оценка DummyClassifier на тестовых данных
y_test_dummy_proba = dummy_model.predict_proba(X_test)[:, 1]  # Вероятности класса "1"
roc_auc_dummy = roc_auc_score(y_test, y_test_dummy_proba)  # Вычисляем ROC-AUC
print(f"ROC-AUC для DummyClassifier на тестовых данных: {roc_auc_dummy:.4f}")

# Сравнение с лучшей моделью
if roc_auc_test > roc_auc_dummy:
    print("Лучшая модель превосходит DummyClassifier.")
else:
    print("Лучшая модель не превосходит DummyClassifier.")
# Out:
# ROC-AUC для DummyClassifier на тестовых данных: 0.5000
# Лучшая модель превосходит DummyClassifier.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Лучшую модель оценили на `test` - отличный результат!

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Аналогично стоит выполнить оценку модели на адеватность - в случае задачи классификации мы можем использовать  `DummyClassifier` (https://scikit-learn.org/stable/modules/generated/sklearn.dummy.DummyClassifier.html#sklearn.dummy.DummyClassifier).

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ### Промежуточный вывод

# %% [markdown]
# <div class='alert alert-info'><b>
#
# Комментарий студента:</b>
#
# Задача классификации решалась с использованием трех моделей: RandomForestClassifier, DecisionTreeClassifier и KNeighborsClassifier. Произведен поиск лучшей модели и оптимальные гиперпараметры, чтобы максимизировать метрику качества ROC-AUC.
#
# Лучшей моделью оказалась RandomForestClassifier (ансамблевая модель на основе деревьев решений).
#
# Оптимальные параметры:
#
# - максимальная глубина деревьев ограничена 5 уровнями.
#
# - минимальное количество объектов для разделения узла - 2.
#
# - в ансамбле используется 200 деревьев.
#
# Выбор RandomForestClassifier как лучшей модели объясняется способностью работать с нелинейными зависимостями и обобщать данные лучше, чем одиночное дерево или k-ближайших соседей.
#
# Метрика ROC-AUC:
#
# - На тренировочных данных: 0.9192.
#
# - На тестовых данных: 0.9227.
#
# Значения ROC-AUC более 0.91 соотвествует условию задачи 2 и  свидетельствуют о том, что модель хорошо справляется с задачей классификации. Разница между ROC-AUC на кросс-валидации и тестовых данных незначительная, что говорит об отсутствии переобучения.
#
# </div>

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# **Описание задачи**
#
# Компания «Работа с заботой» предоставила данные о сотрудниках для решения двух задач:
#
# 1. Предсказание уровня удовлетворённости сотрудников работой на основе доступных характеристик (зарплата, загруженность, уровень должности и тд). Это позволит выявить факторы, влияющие на удовлетворённость, разработать стратегии повышения лояльности сотрудников.
#
# 2. Предсказание увольнений сотрудников на основе данных компании. Эта задача важна, так как внезапные увольнения могут привести к потерям в бизнесе, особенно если уходят ключевые сотрудники.
#
# Для достижения этих целей использованы методы машинного обучения, включая предобработку данных, обучение моделей и оценку с помощью метрик SMAPE и ROC-AUC.
#
# **Этапы работы**
#
# **Задача 1: Предсказание уровня удовлетворённости сотрудников**
#
# 1. Получены тренировочная выборка, входные признаки тестовой выборки и целевой признак `job_satisfaction_rate`.
#
# 2. Проведён анализ распределений признаков, корреляций и влияния на целевую переменную.
#
# 3. Удалены дубликаты и ненужные столбцы (`id`), заполнены пропуски наиболее частыми значениями,выполнено кодирование категориальных признаков (OneHotEncoding и OrdinalEncoding), а также масштабирование числовых признаков.
#
# 4. Создан pipeline для автоматизации предобработки данных и обучения моделей.
#
# 5. Были обучены две модели — линейная регрессия и дерево решений. Для обеих моделей проведён подбор гиперпараметров с использованием GridSearchCV.
#
# 6. Лучшая модель выбрана на основе метрики SMAPE. Это Дерево решений с параметрами:
#
# - Глубина: 12.
#
# - Количество признаков для разбиения: 8.
#
# - Масштабирование числовых признаков: MinMaxScaler.
#
# - Метрика SMAPE на обучающих данных: 15.8598.
#
# - SMAPE на тестовой выборке: 14.2126.
#
# 7. Лучшая модель достигла значения SMAPE < 15 на тестовой выборке, что соответствует заданному качеству предсказаний.
#
# **Задача 2: Предсказание увольнений сотрудников**
#
# 1. Получены тренировочная выборка, входные признаки тестовой выборки и целевой признак `quit`.
#
# 2. Проведён анализ распределений признаков, корреляций и влияния на целевую переменную.
#
# 3. Входной признак `job_satisfaction_rate`, предсказанный лучшей моделью из первой задачи, был добавлен в тестовые данные.
#
# 4. Построен портрет «уволившегося сотрудника», проанализировано влияние уровня удовлетворённости на увольнения.
#
# 5. Выполнена аналогичная предобработка данных, кодирование категориальных признаков и масштабирование числовых.
#
# 4. Были обучены три модели: случайный лес, дерево решений и k-ближайших соседей. Подбор гиперпараметров выполнен с использованием GridSearchCV.
#
# 5. Лучшая модель достигла значения ROC-AUC > 0.91 на тестовой выборке, что соответствует заданному качеству предсказаний.
#
# **Общие выводы:**
#
# Модели показали высокое качество предсказаний. В первой задаче была успешно обучена модель для предсказания уровня удовлетворённости сотрудников. Использование метрики SMAPE позволило выбрать модель, которая минимизирует ошибки (SMAPE = 14.2126). Во второй задаче модель случайного леса продемонстрировала наилучшие результаты (ROC-AUC = 0.9187), что позволяет надёжно прогнозировать увольнения сотрудников.
#
# Уровень удовлетворённости сотрудников тесно связан с увольнениями. Сотрудники с низкой удовлетворённостью чаще покидают компанию. Другие важные факторы текучки кадров включают зарплату, длительность работы в компании, уровень загруженности и оценки руководства.
#
# Результаты исследования помогут HR-отделу выявлять сотрудников с высоким риском увольнения и принимать превентивные меры (повышение зарплаты и должности, улучшение условий труда и тп). Модель предсказания удовлетворённости также может быть использована для анализа текущего состояния сотрудников и разработки программ повышения лояльности.
#
# **Предложения для бизнеса:**
#
# 1. Разработать программы поддержки сотрудников с низким уровнем удовлетворённости (например, карьерное развитие, бонусы за стаж).
#
# 2. Проводить регулярные опросы для мониторинга удовлетворённости и оперативного реагирования на проблемы.
#
# 3. Интегрировать модели предсказания удовлетворённости и увольнений в существующие HR-системы для автоматического анализа рисков.
#
# 4. Исследовать дополнительные факторы (баланс работы и личной жизни, возможности профессионального роста, корпоративная культура) и собрать больше данных для улучшения моделей (отзывы сотрудников, статистика больничных и тп).
#
# 5. Периодически обновлять модели, поскольку условия работы и рынок труда меняются
#
# *Проект решил обе задачи: предсказание уровня удовлетворённости сотрудников и прогнозирование увольнений. Модели демонстрируют высокое качество предсказаний и готовы к внедрению в бизнес-процессы. Использование этих инструментов поможет компании «Работа с заботой» повысить лояльность сотрудников, снизить отток и минимизировать риски.*

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Есть итоговый вывод.

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: общий вывод по проекту.
#
# Геннадий, проект получился на довольно хорошем уровне - отличная работа над проектом, молодец!
#
# Мне нравится твой аналитический подход к выполнению проекта, ты соблюдаешь структуру работы, выполняешь её последовательно - это очень хорошо! Шаги проекта выполнены по порядку согласно плану проекта, нет смысловых и структурных ям. Важно, что не забываешь про выводы.
#
# Работа с моделями также выполнена отлично: исследовано несколько алгоритмов, проведён подбор гиперпараметров с помощью `GridSearchCV`, выполнена промежуточная оценка моделей на кросс-валидации - молодец! Здорово, что используешь сочетание `ColumnTransformer` и `Pipeline` для соединения разных инструментов в единый модельный объект и настраиваешь бесперебойную работу энкодера в случае появления в данных новых, неизвестных на момент обучения значений признаков - так твоё решение будет более гибким и масштабируемым.
#
# Над проектом ещё стоит поработать - есть рекомендации по дополнению некоторых твоих шагов проекта. Такие рекомендации я отметил жёлтыми комментариями. Будет здорово, если ты учтёшь их - так проект станет структурно и содержательно более совершенным.
#
# Также в работе есть критические замечания. К этим замечаниям я оставил пояснительные комментарии красного цвета, в которых перечислил возможные варианты дальнейших действий. Уверен, ты быстро с этим управишься:)
#
# Если о том, что нужно сделать в рамках комментариев, будут возникать вопросы - оставь их, пожалуйста, в комментариях, и я отвечу на них во время следующего ревью.
#
# Также буду рад ответить на любые твои вопросы по проекту или на какие-либо другие, если они у тебя имеются - оставь их в комментариях, и я постараюсь ответить:)
#
# Жду твой проект на повторном ревью. До встречи:)

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: итоговый вывод по проекту.
#
# Геннадий, все замечания учтены - проект принят!
#
# Спасибо за хорошую работу над проектом, желаю успехов в дальнейшем обучении:)
